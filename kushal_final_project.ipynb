# %%
import pandas as pd
import random

# List of Nike items
nike_items = [
    "Running Shoes",      # Popular for running and casual wear
    "Soccer Shoes",       # Used for playing soccer/football
    "Socks",              # Sports socks, ankle socks, etc.
    "Swimming Shirt",     # For swimming and water sports
    "Dry Fit V-Neck",     # A moisture-wicking athletic shirt
    "Rash Guard",         # Protective wear for water sports or workouts
    "Sweatshirts",        # For warmth and casual wear
    "Hoodies",            # Casual or sports hoodies for colder weather
    "Tech Pants",         # Performance pants for sports or training
    "Modern Pants"        # Fashionable casual or sports pants
]

# List of Amazon items
amazon_items = [
    "Echo Dot",           # Smart speaker
    "Kindle Paperwhite",   # E-reader
    "Fire TV Stick",       # Streaming device
    "Wireless Mouse",      # Computer accessory
    "Bluetooth Speaker",   # Portable speaker
    "Phone Charger",       # USB charger
    "Fitness Tracker",     # Wearable fitness device
    "Laptop Sleeve",       # Protective case for laptops
    "Smart Light Bulbs",   # Home automation lighting
    "Noise Cancelling Headphones"  # Audio accessory
]

# List of Walmart items
walmart_items = [
    "BBQ Grill",          # Outdoor grill
    "Vacuum Cleaner",     # Home cleaning device
    "Microwave Oven",     # Kitchen appliance
    "Blender",            # Kitchen appliance
    "Towel Set",          # Bathroom accessory
    "Camping Tent",       # Outdoor tent for camping
    "Yoga Mat",           # Fitness accessory
    "Office Chair",       # Furniture
    "Electric Kettle",    # Kitchen appliance
    "Air Fryer"           # Kitchen appliance
]

# Create 20 transactions for each store (Nike, Amazon, and Walmart)
all_transactions = []
stores = {
    "Nike": nike_items,
    "Amazon": amazon_items,
    "Walmart": walmart_items
}

for store, items in stores.items():
    for i in range(1, 21):
        num_items = random.randint(2, 6)  # Each transaction will have 2 to 6 items
        transaction_items = random.sample(items, num_items)
        all_transactions.append({
            "Transaction ID": f"{store}Trans{i}",
            "Store": store,
            "Items": ", ".join(transaction_items)
        })

# Convert to DataFrame
df_transactions = pd.DataFrame(all_transactions)

# Save to CSV
df_transactions.to_csv("store_transactions.csv", index=False)

print("Transactions saved to 'store_transactions.csv'.")
# Out:
# Transactions saved to 'store_transactions.csv'.

# %%
import pandas as pd
import random

# Define the Nike items
nike_items = [
    "Running Shoes",
    "Soccer Shoes",
    "Socks",
    "Swimming Shirt",
    "Dry Fit V-Neck",
    "Rash Guard",
    "Sweatshirts",
    "Hoodies",
    "Tech Pants",
    "Modern Pants"
]

# Define the Amazon items
amazon_items = [
    "Echo Dot",
    "Kindle Paperwhite",
    "Fire TV Stick",
    "Wireless Mouse",
    "Bluetooth Speaker",
    "Phone Charger",
    "Fitness Tracker",
    "Laptop Sleeve",
    "Smart Light Bulbs",
    "Noise Cancelling Headphones"
]

# Define the Walmart items
walmart_items = [
    "BBQ Grill",
    "Vacuum Cleaner",
    "Microwave Oven",
    "Blender",
    "Towel Set",
    "Camping Tent",
    "Yoga Mat",
    "Office Chair",
    "Electric Kettle",
    "Air Fryer"
]

# Define transactions for each database (Nike, Amazon, Walmart)
transactions_db_nike = [
    ["Running Shoes", "Socks", "Sweatshirts"],
    ["Soccer Shoes", "Socks"],
    ["Swimming Shirt", "Dry Fit V-Neck"],
    ["Rash Guard", "Hoodies", "Tech Pants"],
    ["Modern Pants", "Sweatshirts"],
    # Add more as needed
]

transactions_db_amazon = [
    ["Echo Dot", "Fire TV Stick"],
    ["Kindle Paperwhite", "Phone Charger", "Wireless Mouse"],
    ["Fitness Tracker", "Smart Light Bulbs"],
    ["Bluetooth Speaker", "Noise Cancelling Headphones"],
    ["Laptop Sleeve", "Echo Dot", "Phone Charger"],
    # Add more as needed
]

transactions_db_walmart = [
    ["BBQ Grill", "Camping Tent"],
    ["Vacuum Cleaner", "Air Fryer"],
    ["Blender", "Yoga Mat", "Towel Set"],
    ["Microwave Oven", "Electric Kettle"],
    ["Office Chair", "Blender"],
    # Add more as needed
]

# Function to save transactions to CSV
def save_transactions(transactions, db_number, store_name):
    df_transactions = pd.DataFrame({
        "Transaction ID": [f"{store_name}Trans{j+1} DB{db_number}" for j in range(len(transactions))],
        "Items": [", ".join(transaction) for transaction in transactions]
    })
    df_transactions.to_csv(f"{store_name.lower()}_transactions_db{db_number}.csv", index=False)

# Save each Nike, Amazon, and Walmart database
save_transactions(transactions_db_nike, 1, "Nike")
save_transactions(transactions_db_amazon, 1, "Amazon")
save_transactions(transactions_db_walmart, 1, "Walmart")

print("Nike, Amazon, and Walmart databases saved successfully!")
# Out:
# Nike, Amazon, and Walmart databases saved successfully!

# %%
import pandas as pd
from itertools import combinations
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.frequent_patterns import fpgrowth
import time

# Define Nike, Amazon, and Walmart items for all transactions
nike_items = [
    "Running Shoes", "Soccer Shoes", "Socks", "Swimming Shirt", "Dry Fit V-Neck",
    "Rash Guard", "Sweatshirts", "Hoodies", "Tech Pants", "Modern Pants"
]

amazon_items = [
    "Echo Dot", "Kindle Paperwhite", "Fire TV Stick", "Wireless Mouse", "Bluetooth Speaker",
    "Phone Charger", "Fitness Tracker", "Laptop Sleeve", "Smart Light Bulbs", "Noise Cancelling Headphones"
]

walmart_items = [
    "BBQ Grill", "Vacuum Cleaner", "Microwave Oven", "Blender", "Towel Set",
    "Camping Tent", "Yoga Mat", "Office Chair", "Electric Kettle", "Air Fryer"
]

# Transactions for Nike, Amazon, and Walmart
transactions_db = {
    'Nike': [
        ["Running Shoes", "Socks", "Sweatshirts"], ["Soccer Shoes", "Socks"], ["Swimming Shirt", "Dry Fit V-Neck"],
        ["Rash Guard", "Hoodies", "Tech Pants"], ["Modern Pants", "Sweatshirts"]
    ],
    'Amazon': [
        ["Echo Dot", "Fire TV Stick"], ["Kindle Paperwhite", "Phone Charger", "Wireless Mouse"],
        ["Fitness Tracker", "Smart Light Bulbs"], ["Bluetooth Speaker", "Noise Cancelling Headphones"],
        ["Laptop Sleeve", "Echo Dot", "Phone Charger"]
    ],
    'Walmart': [
        ["BBQ Grill", "Camping Tent"], ["Vacuum Cleaner", "Air Fryer"], ["Blender", "Yoga Mat", "Towel Set"],
        ["Microwave Oven", "Electric Kettle"], ["Office Chair", "Blender"]
    ]
}

# Prompt user for input
min_support = float(input("Enter minimum support (e.g., 0.2): "))
min_confidence = float(input("Enter minimum confidence (e.g., 0.7): "))

# Convert transactions to DataFrame with binary encoding for apriori and fp-growth
def encode_transactions(transactions, items):
    encoded_vals = []
    for transaction in transactions:
        encoded_transaction = {item: (item in transaction) for item in items}
        encoded_vals.append(encoded_transaction)
    return pd.DataFrame(encoded_vals)

# Brute Force Implementation
def brute_force(transactions, items, min_support):
    start_time = time.time()

    def calculate_support(itemset, transactions):
        count = 0
        for transaction in transactions:
            if itemset.issubset(transaction):
                count += 1
        return count / len(transactions)

    def find_frequent_itemsets(items, transactions, size, min_support):
        itemsets = [set(combo) for combo in combinations(items, size)]
        frequent_itemsets = []
        for itemset in itemsets:
            support = calculate_support(itemset, transactions)
            if support >= min_support:
                frequent_itemsets.append((itemset, support))
        return frequent_itemsets

    k = 1
    frequent_itemsets = []
    while True:
        current_frequent_itemsets = find_frequent_itemsets(items, transactions, k, min_support)
        if len(current_frequent_itemsets) == 0:
            break
        frequent_itemsets.extend(current_frequent_itemsets)
        k += 1

    # Generate association rules
    rules = []
    for itemset, support in frequent_itemsets:
        if len(itemset) > 1:
            for consequent in itemset:
                antecedent = itemset - {consequent}
                if len(antecedent) > 0:
                    confidence = calculate_support(itemset, transactions) / calculate_support(antecedent, transactions)
                    if confidence >= min_confidence:
                        rules.append((antecedent, consequent, confidence))

    brute_force_time = time.time() - start_time
    return frequent_itemsets, rules, brute_force_time

# Apriori Implementation
def apriori_algorithm(df, min_support, min_confidence):
    start_time = time.time()
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    apriori_time = time.time() - start_time
    return frequent_itemsets, rules, apriori_time

# FP-Growth Implementation
def fpgrowth_algorithm(df, min_support, min_confidence):
    start_time = time.time()
    frequent_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    fpgrowth_time = time.time() - start_time
    return frequent_itemsets, rules, fpgrowth_time

# Main comparison function
def compare_algorithms(transactions_db, items, min_support, min_confidence):
    for store, transactions in transactions_db.items():
        print(f"\n--- Store: {store} ---")
        transactions = [set(t) for t in transactions]
        item_list = nike_items if store == 'Nike' else amazon_items if store == 'Amazon' else walmart_items

        # Brute Force
        frequent_itemsets_bf, rules_bf, bf_time = brute_force(transactions, item_list, min_support)
        print(f"Brute Force Time: {bf_time:.4f} seconds")
        print(f"Frequent Itemsets (Brute Force): {frequent_itemsets_bf}")
        print(f"Association Rules (Brute Force): {rules_bf}")

        # Apriori
        df_encoded = encode_transactions(transactions, item_list)
        frequent_itemsets_ap, rules_ap, ap_time = apriori_algorithm(df_encoded, min_support, min_confidence)
        print(f"Apriori Time: {ap_time:.4f} seconds")
        print(f"Frequent Itemsets (Apriori):\n{frequent_itemsets_ap}")
        print(f"Association Rules (Apriori):\n{rules_ap}")

        # FP-Growth
        frequent_itemsets_fp, rules_fp, fp_time = fpgrowth_algorithm(df_encoded, min_support, min_confidence)
        print(f"FP-Growth Time: {fp_time:.4f} seconds")
        print(f"Frequent Itemsets (FP-Growth):\n{frequent_itemsets_fp}")
        print(f"Association Rules (FP-Growth):\n{rules_fp}")

# Run the comparison for all stores and their databases
compare_algorithms(transactions_db, nike_items, min_support, min_confidence)
# Out:
# Enter minimum support (e.g., 0.2): 0.1
# Enter minimum confidence (e.g., 0.7): 0.8
#
# --- Store: Nike ---
# Brute Force Time: 0.0008 seconds
# Frequent Itemsets (Brute Force): [({'Running Shoes'}, 0.2), ({'Soccer Shoes'}, 0.2), ({'Socks'}, 0.4), ({'Swimming Shirt'}, 0.2), ({'Dry Fit V-Neck'}, 0.2), ({'Rash Guard'}, 0.2), ({'Sweatshirts'}, 0.4), ({'Hoodies'}, 0.2), ({'Tech Pants'}, 0.2), ({'Modern Pants'}, 0.2), ({'Socks', 'Running Shoes'}, 0.2), ({'Running Shoes', 'Sweatshirts'}, 0.2), ({'Socks', 'Soccer Shoes'}, 0.2), ({'Socks', 'Sweatshirts'}, 0.2), ({'Swimming Shirt', 'Dry Fit V-Neck'}, 0.2), ({'Rash Guard', 'Hoodies'}, 0.2), ({'Rash Guard', 'Tech Pants'}, 0.2), ({'Modern Pants', 'Sweatshirts'}, 0.2), ({'Hoodies', 'Tech Pants'}, 0.2), ({'Socks', 'Running Shoes', 'Sweatshirts'}, 0.2), ({'Rash Guard', 'Hoodies', 'Tech Pants'}, 0.2)]
# Association Rules (Brute Force): [({'Running Shoes'}, 'Socks', 1.0), ({'Running Shoes'}, 'Sweatshirts', 1.0), ({'Soccer Shoes'}, 'Socks', 1.0), ({'Dry Fit V-Neck'}, 'Swimming Shirt', 1.0), ({'Swimming Shirt'}, 'Dry Fit V-Neck', 1.0), ({'Hoodies'}, 'Rash Guard', 1.0), ({'Rash Guard'}, 'Hoodies', 1.0), ({'Tech Pants'}, 'Rash Guard', 1.0), ({'Rash Guard'}, 'Tech Pants', 1.0), ({'Modern Pants'}, 'Sweatshirts', 1.0), ({'Tech Pants'}, 'Hoodies', 1.0), ({'Hoodies'}, 'Tech Pants', 1.0), ({'Running Shoes', 'Sweatshirts'}, 'Socks', 1.0), ({'Socks', 'Sweatshirts'}, 'Running Shoes', 1.0), ({'Running Shoes', 'Socks'}, 'Sweatshirts', 1.0), ({'Hoodies', 'Tech Pants'}, 'Rash Guard', 1.0), ({'Rash Guard', 'Tech Pants'}, 'Hoodies', 1.0), ({'Rash Guard', 'Hoodies'}, 'Tech Pants', 1.0)]
# Apriori Time: 0.0089 seconds
# Frequent Itemsets (Apriori):
#     support                             itemsets
# 0       0.2                      (Running Shoes)
# 1       0.2                       (Soccer Shoes)
# 2       0.4                              (Socks)
# 3       0.2                     (Swimming Shirt)
# 4       0.2                     (Dry Fit V-Neck)
# 5       0.2                         (Rash Guard)
# 6       0.4                        (Sweatshirts)
# 7       0.2                            (Hoodies)
# 8       0.2                         (Tech Pants)
# 9       0.2                       (Modern Pants)
# 10      0.2               (Socks, Running Shoes)
# 11      0.2         (Running Shoes, Sweatshirts)
# 12      0.2                (Socks, Soccer Shoes)
# 13      0.2                 (Socks, Sweatshirts)
# 14      0.2     (Swimming Shirt, Dry Fit V-Neck)
# 15      0.2                (Rash Guard, Hoodies)
# 16      0.2             (Rash Guard, Tech Pants)
# 17      0.2          (Modern Pants, Sweatshirts)
# 18      0.2                (Hoodies, Tech Pants)
# 19      0.2  (Socks, Running Shoes, Sweatshirts)
# 20      0.2    (Rash Guard, Hoodies, Tech Pants)
# Association Rules (Apriori):
#                      antecedents               consequents  \
# 0                (Running Shoes)                   (Socks)
# 1                (Running Shoes)             (Sweatshirts)
# 2                 (Soccer Shoes)                   (Socks)
# 3               (Swimming Shirt)          (Dry Fit V-Neck)
# 4               (Dry Fit V-Neck)          (Swimming Shirt)
# 5                   (Rash Guard)                 (Hoodies)
# 6                      (Hoodies)              (Rash Guard)
# 7                   (Rash Guard)              (Tech Pants)
# 8                   (Tech Pants)              (Rash Guard)
# 9                 (Modern Pants)             (Sweatshirts)
# 10                     (Hoodies)              (Tech Pants)
# 11                  (Tech Pants)                 (Hoodies)
# 12        (Running Shoes, Socks)             (Sweatshirts)
# 13          (Socks, Sweatshirts)           (Running Shoes)
# 14  (Running Shoes, Sweatshirts)                   (Socks)
# 15               (Running Shoes)      (Socks, Sweatshirts)
# 16         (Rash Guard, Hoodies)              (Tech Pants)
# 17      (Rash Guard, Tech Pants)                 (Hoodies)
# 18         (Hoodies, Tech Pants)              (Rash Guard)
# 19                  (Rash Guard)     (Hoodies, Tech Pants)
# 20                     (Hoodies)  (Rash Guard, Tech Pants)
# 21                  (Tech Pants)     (Rash Guard, Hoodies)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 0                  0.2                 0.4      0.2         1.0   2.5
# 1                  0.2                 0.4      0.2         1.0   2.5
# 2                  0.2                 0.4      0.2         1.0   2.5
# 3                  0.2                 0.2      0.2         1.0   5.0
# 4                  0.2                 0.2      0.2         1.0   5.0
# 5                  0.2                 0.2      0.2         1.0   5.0
# 6                  0.2                 0.2      0.2         1.0   5.0
# 7                  0.2                 0.2      0.2         1.0   5.0
# 8                  0.2                 0.2      0.2         1.0   5.0
# 9                  0.2                 0.4      0.2         1.0   2.5
# 10                 0.2                 0.2      0.2         1.0   5.0
# 11                 0.2                 0.2      0.2         1.0   5.0
# 12                 0.2                 0.4      0.2         1.0   2.5
# 13                 0.2                 0.2      0.2         1.0   5.0
# 14                 0.2                 0.4      0.2         1.0   2.5
# 15                 0.2                 0.2      0.2         1.0   5.0
# 16                 0.2                 0.2      0.2         1.0   5.0
# 17                 0.2                 0.2      0.2         1.0   5.0
# 18                 0.2                 0.2      0.2         1.0   5.0
# 19                 0.2                 0.2      0.2         1.0   5.0
# 20                 0.2                 0.2      0.2         1.0   5.0
# 21                 0.2                 0.2      0.2         1.0   5.0
#
#     leverage  conviction  zhangs_metric
# 0       0.12         inf           0.75
# 1       0.12         inf           0.75
# 2       0.12         inf           0.75
# 3       0.16         inf           1.00
# 4       0.16         inf           1.00
# 5       0.16         inf           1.00
# 6       0.16         inf           1.00
# 7       0.16         inf           1.00
# 8       0.16         inf           1.00
# 9       0.12         inf           0.75
# 10      0.16         inf           1.00
# 11      0.16         inf           1.00
# 12      0.12         inf           0.75
# 13      0.16         inf           1.00
# 14      0.12         inf           0.75
# 15      0.16         inf           1.00
# 16      0.16         inf           1.00
# 17      0.16         inf           1.00
# 18      0.16         inf           1.00
# 19      0.16         inf           1.00
# 20      0.16         inf           1.00
# 21      0.16         inf           1.00
# FP-Growth Time: 0.0055 seconds
# Frequent Itemsets (FP-Growth):
#     support                             itemsets
# 0       0.4                        (Sweatshirts)
# 1       0.4                              (Socks)
# 2       0.2                      (Running Shoes)
# 3       0.2                       (Soccer Shoes)
# 4       0.2                     (Dry Fit V-Neck)
# 5       0.2                     (Swimming Shirt)
# 6       0.2                         (Tech Pants)
# 7       0.2                            (Hoodies)
# 8       0.2                         (Rash Guard)
# 9       0.2                       (Modern Pants)
# 10      0.2                 (Socks, Sweatshirts)
# 11      0.2               (Socks, Running Shoes)
# 12      0.2         (Running Shoes, Sweatshirts)
# 13      0.2  (Socks, Running Shoes, Sweatshirts)
# 14      0.2                (Socks, Soccer Shoes)
# 15      0.2     (Swimming Shirt, Dry Fit V-Neck)
# 16      0.2                (Hoodies, Tech Pants)
# 17      0.2                (Rash Guard, Hoodies)
# 18      0.2             (Rash Guard, Tech Pants)
# 19      0.2    (Rash Guard, Hoodies, Tech Pants)
# 20      0.2          (Modern Pants, Sweatshirts)
# Association Rules (FP-Growth):
#                      antecedents               consequents  \
# 0                (Running Shoes)                   (Socks)
# 1                (Running Shoes)             (Sweatshirts)
# 2         (Running Shoes, Socks)             (Sweatshirts)
# 3           (Socks, Sweatshirts)           (Running Shoes)
# 4   (Running Shoes, Sweatshirts)                   (Socks)
# 5                (Running Shoes)      (Socks, Sweatshirts)
# 6                 (Soccer Shoes)                   (Socks)
# 7               (Swimming Shirt)          (Dry Fit V-Neck)
# 8               (Dry Fit V-Neck)          (Swimming Shirt)
# 9                      (Hoodies)              (Tech Pants)
# 10                  (Tech Pants)                 (Hoodies)
# 11                  (Rash Guard)                 (Hoodies)
# 12                     (Hoodies)              (Rash Guard)
# 13                  (Rash Guard)              (Tech Pants)
# 14                  (Tech Pants)              (Rash Guard)
# 15         (Rash Guard, Hoodies)              (Tech Pants)
# 16      (Rash Guard, Tech Pants)                 (Hoodies)
# 17         (Hoodies, Tech Pants)              (Rash Guard)
# 18                  (Rash Guard)     (Hoodies, Tech Pants)
# 19                     (Hoodies)  (Rash Guard, Tech Pants)
# 20                  (Tech Pants)     (Rash Guard, Hoodies)
# 21                (Modern Pants)             (Sweatshirts)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 0                  0.2                 0.4      0.2         1.0   2.5
# 1                  0.2                 0.4      0.2         1.0   2.5
# 2                  0.2                 0.4      0.2         1.0   2.5
# 3                  0.2                 0.2      0.2         1.0   5.0
# 4                  0.2                 0.4      0.2         1.0   2.5
# 5                  0.2                 0.2      0.2         1.0   5.0
# 6                  0.2                 0.4      0.2         1.0   2.5
# 7                  0.2                 0.2      0.2         1.0   5.0
# 8                  0.2                 0.2      0.2         1.0   5.0
# 9                  0.2                 0.2      0.2         1.0   5.0
# 10                 0.2                 0.2      0.2         1.0   5.0
# 11                 0.2                 0.2      0.2         1.0   5.0
# 12                 0.2                 0.2      0.2         1.0   5.0
# 13                 0.2                 0.2      0.2         1.0   5.0
# 14                 0.2                 0.2      0.2         1.0   5.0
# 15                 0.2                 0.2      0.2         1.0   5.0
# 16                 0.2                 0.2      0.2         1.0   5.0
# 17                 0.2                 0.2      0.2         1.0   5.0
# 18                 0.2                 0.2      0.2         1.0   5.0
# 19                 0.2                 0.2      0.2         1.0   5.0
# 20                 0.2                 0.2      0.2         1.0   5.0
# 21                 0.2                 0.4      0.2         1.0   2.5
#
#     leverage  conviction  zhangs_metric
# 0       0.12         inf           0.75
# 1       0.12         inf           0.75
# 2       0.12         inf           0.75
# 3       0.16         inf           1.00
# 4       0.12         inf           0.75
# 5       0.16         inf           1.00
# 6       0.12         inf           0.75
# 7       0.16         inf           1.00
# 8       0.16         inf           1.00
# 9       0.16         inf           1.00
# 10      0.16         inf           1.00
# 11      0.16         inf           1.00
# 12      0.16         inf           1.00
# 13      0.16         inf           1.00
# 14      0.16         inf           1.00
# 15      0.16         inf           1.00
# 16      0.16         inf           1.00
# 17      0.16         inf           1.00
# 18      0.16         inf           1.00
# 19      0.16         inf           1.00
# 20      0.16         inf           1.00
# 21      0.12         inf           0.75
#
# --- Store: Amazon ---
# Brute Force Time: 0.0005 seconds
# Frequent Itemsets (Brute Force): [({'Echo Dot'}, 0.4), ({'Kindle Paperwhite'}, 0.2), ({'Fire TV Stick'}, 0.2), ({'Wireless Mouse'}, 0.2), ({'Bluetooth Speaker'}, 0.2), ({'Phone Charger'}, 0.4), ({'Fitness Tracker'}, 0.2), ({'Laptop Sleeve'}, 0.2), ({'Smart Light Bulbs'}, 0.2), ({'Noise Cancelling Headphones'}, 0.2), ({'Fire TV Stick', 'Echo Dot'}, 0.2), ({'Phone Charger', 'Echo Dot'}, 0.2), ({'Laptop Sleeve', 'Echo Dot'}, 0.2), ({'Kindle Paperwhite', 'Wireless Mouse'}, 0.2), ({'Phone Charger', 'Kindle Paperwhite'}, 0.2), ({'Phone Charger', 'Wireless Mouse'}, 0.2), ({'Noise Cancelling Headphones', 'Bluetooth Speaker'}, 0.2), ({'Phone Charger', 'Laptop Sleeve'}, 0.2), ({'Smart Light Bulbs', 'Fitness Tracker'}, 0.2), ({'Phone Charger', 'Laptop Sleeve', 'Echo Dot'}, 0.2), ({'Phone Charger', 'Kindle Paperwhite', 'Wireless Mouse'}, 0.2)]
# Association Rules (Brute Force): [({'Fire TV Stick'}, 'Echo Dot', 1.0), ({'Laptop Sleeve'}, 'Echo Dot', 1.0), ({'Wireless Mouse'}, 'Kindle Paperwhite', 1.0), ({'Kindle Paperwhite'}, 'Wireless Mouse', 1.0), ({'Kindle Paperwhite'}, 'Phone Charger', 1.0), ({'Wireless Mouse'}, 'Phone Charger', 1.0), ({'Bluetooth Speaker'}, 'Noise Cancelling Headphones', 1.0), ({'Noise Cancelling Headphones'}, 'Bluetooth Speaker', 1.0), ({'Laptop Sleeve'}, 'Phone Charger', 1.0), ({'Fitness Tracker'}, 'Smart Light Bulbs', 1.0), ({'Smart Light Bulbs'}, 'Fitness Tracker', 1.0), ({'Laptop Sleeve', 'Echo Dot'}, 'Phone Charger', 1.0), ({'Phone Charger', 'Echo Dot'}, 'Laptop Sleeve', 1.0), ({'Phone Charger', 'Laptop Sleeve'}, 'Echo Dot', 1.0), ({'Kindle Paperwhite', 'Wireless Mouse'}, 'Phone Charger', 1.0), ({'Phone Charger', 'Wireless Mouse'}, 'Kindle Paperwhite', 1.0), ({'Phone Charger', 'Kindle Paperwhite'}, 'Wireless Mouse', 1.0)]
# Apriori Time: 0.0113 seconds
# Frequent Itemsets (Apriori):
#     support                                           itemsets
# 0       0.4                                         (Echo Dot)
# 1       0.2                                (Kindle Paperwhite)
# 2       0.2                                    (Fire TV Stick)
# 3       0.2                                   (Wireless Mouse)
# 4       0.2                                (Bluetooth Speaker)
# 5       0.4                                    (Phone Charger)
# 6       0.2                                  (Fitness Tracker)
# 7       0.2                                    (Laptop Sleeve)
# 8       0.2                                (Smart Light Bulbs)
# 9       0.2                      (Noise Cancelling Headphones)
# 10      0.2                          (Fire TV Stick, Echo Dot)
# 11      0.2                          (Phone Charger, Echo Dot)
# 12      0.2                          (Laptop Sleeve, Echo Dot)
# 13      0.2                (Kindle Paperwhite, Wireless Mouse)
# 14      0.2                 (Phone Charger, Kindle Paperwhite)
# 15      0.2                    (Phone Charger, Wireless Mouse)
# 16      0.2   (Noise Cancelling Headphones, Bluetooth Speaker)
# 17      0.2                     (Phone Charger, Laptop Sleeve)
# 18      0.2               (Smart Light Bulbs, Fitness Tracker)
# 19      0.2           (Phone Charger, Laptop Sleeve, Echo Dot)
# 20      0.2  (Phone Charger, Kindle Paperwhite, Wireless Mo...
# Association Rules (Apriori):
#                             antecedents                         consequents  \
# 0                       (Fire TV Stick)                          (Echo Dot)
# 1                       (Laptop Sleeve)                          (Echo Dot)
# 2                   (Kindle Paperwhite)                    (Wireless Mouse)
# 3                      (Wireless Mouse)                 (Kindle Paperwhite)
# 4                   (Kindle Paperwhite)                     (Phone Charger)
# 5                      (Wireless Mouse)                     (Phone Charger)
# 6         (Noise Cancelling Headphones)                 (Bluetooth Speaker)
# 7                   (Bluetooth Speaker)       (Noise Cancelling Headphones)
# 8                       (Laptop Sleeve)                     (Phone Charger)
# 9                   (Smart Light Bulbs)                   (Fitness Tracker)
# 10                    (Fitness Tracker)                 (Smart Light Bulbs)
# 11       (Phone Charger, Laptop Sleeve)                          (Echo Dot)
# 12            (Phone Charger, Echo Dot)                     (Laptop Sleeve)
# 13            (Laptop Sleeve, Echo Dot)                     (Phone Charger)
# 14                      (Laptop Sleeve)           (Phone Charger, Echo Dot)
# 15   (Phone Charger, Kindle Paperwhite)                    (Wireless Mouse)
# 16      (Phone Charger, Wireless Mouse)                 (Kindle Paperwhite)
# 17  (Kindle Paperwhite, Wireless Mouse)                     (Phone Charger)
# 18                  (Kindle Paperwhite)     (Phone Charger, Wireless Mouse)
# 19                     (Wireless Mouse)  (Phone Charger, Kindle Paperwhite)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 0                  0.2                 0.4      0.2         1.0   2.5
# 1                  0.2                 0.4      0.2         1.0   2.5
# 2                  0.2                 0.2      0.2         1.0   5.0
# 3                  0.2                 0.2      0.2         1.0   5.0
# 4                  0.2                 0.4      0.2         1.0   2.5
# 5                  0.2                 0.4      0.2         1.0   2.5
# 6                  0.2                 0.2      0.2         1.0   5.0
# 7                  0.2                 0.2      0.2         1.0   5.0
# 8                  0.2                 0.4      0.2         1.0   2.5
# 9                  0.2                 0.2      0.2         1.0   5.0
# 10                 0.2                 0.2      0.2         1.0   5.0
# 11                 0.2                 0.4      0.2         1.0   2.5
# 12                 0.2                 0.2      0.2         1.0   5.0
# 13                 0.2                 0.4      0.2         1.0   2.5
# 14                 0.2                 0.2      0.2         1.0   5.0
# 15                 0.2                 0.2      0.2         1.0   5.0
# 16                 0.2                 0.2      0.2         1.0   5.0
# 17                 0.2                 0.4      0.2         1.0   2.5
# 18                 0.2                 0.2      0.2         1.0   5.0
# 19                 0.2                 0.2      0.2         1.0   5.0
#
#     leverage  conviction  zhangs_metric
# 0       0.12         inf           0.75
# 1       0.12         inf           0.75
# 2       0.16         inf           1.00
# 3       0.16         inf           1.00
# 4       0.12         inf           0.75
# 5       0.12         inf           0.75
# 6       0.16         inf           1.00
# 7       0.16         inf           1.00
# 8       0.12         inf           0.75
# 9       0.16         inf           1.00
# 10      0.16         inf           1.00
# 11      0.12         inf           0.75
# 12      0.16         inf           1.00
# 13      0.12         inf           0.75
# 14      0.16         inf           1.00
# 15      0.16         inf           1.00
# 16      0.16         inf           1.00
# 17      0.12         inf           0.75
# 18      0.16         inf           1.00
# 19      0.16         inf           1.00
# FP-Growth Time: 0.0049 seconds
# Frequent Itemsets (FP-Growth):
#     support                                           itemsets
# 0       0.4                                         (Echo Dot)
# 1       0.2                                    (Fire TV Stick)
# 2       0.4                                    (Phone Charger)
# 3       0.2                                   (Wireless Mouse)
# 4       0.2                                (Kindle Paperwhite)
# 5       0.2                                (Smart Light Bulbs)
# 6       0.2                                  (Fitness Tracker)
# 7       0.2                      (Noise Cancelling Headphones)
# 8       0.2                                (Bluetooth Speaker)
# 9       0.2                                    (Laptop Sleeve)
# 10      0.2                          (Phone Charger, Echo Dot)
# 11      0.2                          (Fire TV Stick, Echo Dot)
# 12      0.2                    (Phone Charger, Wireless Mouse)
# 13      0.2                (Kindle Paperwhite, Wireless Mouse)
# 14      0.2                 (Phone Charger, Kindle Paperwhite)
# 15      0.2  (Phone Charger, Kindle Paperwhite, Wireless Mo...
# 16      0.2               (Smart Light Bulbs, Fitness Tracker)
# 17      0.2   (Noise Cancelling Headphones, Bluetooth Speaker)
# 18      0.2                          (Laptop Sleeve, Echo Dot)
# 19      0.2                     (Phone Charger, Laptop Sleeve)
# 20      0.2           (Phone Charger, Laptop Sleeve, Echo Dot)
# Association Rules (FP-Growth):
#                             antecedents                         consequents  \
# 0                       (Fire TV Stick)                          (Echo Dot)
# 1                      (Wireless Mouse)                     (Phone Charger)
# 2                   (Kindle Paperwhite)                    (Wireless Mouse)
# 3                      (Wireless Mouse)                 (Kindle Paperwhite)
# 4                   (Kindle Paperwhite)                     (Phone Charger)
# 5    (Phone Charger, Kindle Paperwhite)                    (Wireless Mouse)
# 6       (Phone Charger, Wireless Mouse)                 (Kindle Paperwhite)
# 7   (Kindle Paperwhite, Wireless Mouse)                     (Phone Charger)
# 8                   (Kindle Paperwhite)     (Phone Charger, Wireless Mouse)
# 9                      (Wireless Mouse)  (Phone Charger, Kindle Paperwhite)
# 10                  (Smart Light Bulbs)                   (Fitness Tracker)
# 11                    (Fitness Tracker)                 (Smart Light Bulbs)
# 12        (Noise Cancelling Headphones)                 (Bluetooth Speaker)
# 13                  (Bluetooth Speaker)       (Noise Cancelling Headphones)
# 14                      (Laptop Sleeve)                          (Echo Dot)
# 15                      (Laptop Sleeve)                     (Phone Charger)
# 16       (Phone Charger, Laptop Sleeve)                          (Echo Dot)
# 17            (Phone Charger, Echo Dot)                     (Laptop Sleeve)
# 18            (Laptop Sleeve, Echo Dot)                     (Phone Charger)
# 19                      (Laptop Sleeve)           (Phone Charger, Echo Dot)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 0                  0.2                 0.4      0.2         1.0   2.5
# 1                  0.2                 0.4      0.2         1.0   2.5
# 2                  0.2                 0.2      0.2         1.0   5.0
# 3                  0.2                 0.2      0.2         1.0   5.0
# 4                  0.2                 0.4      0.2         1.0   2.5
# 5                  0.2                 0.2      0.2         1.0   5.0
# 6                  0.2                 0.2      0.2         1.0   5.0
# 7                  0.2                 0.4      0.2         1.0   2.5
# 8                  0.2                 0.2      0.2         1.0   5.0
# 9                  0.2                 0.2      0.2         1.0   5.0
# 10                 0.2                 0.2      0.2         1.0   5.0
# 11                 0.2                 0.2      0.2         1.0   5.0
# 12                 0.2                 0.2      0.2         1.0   5.0
# 13                 0.2                 0.2      0.2         1.0   5.0
# 14                 0.2                 0.4      0.2         1.0   2.5
# 15                 0.2                 0.4      0.2         1.0   2.5
# 16                 0.2                 0.4      0.2         1.0   2.5
# 17                 0.2                 0.2      0.2         1.0   5.0
# 18                 0.2                 0.4      0.2         1.0   2.5
# 19                 0.2                 0.2      0.2         1.0   5.0
#
#     leverage  conviction  zhangs_metric
# 0       0.12         inf           0.75
# 1       0.12         inf           0.75
# 2       0.16         inf           1.00
# 3       0.16         inf           1.00
# 4       0.12         inf           0.75
# 5       0.16         inf           1.00
# 6       0.16         inf           1.00
# 7       0.12         inf           0.75
# 8       0.16         inf           1.00
# 9       0.16         inf           1.00
# 10      0.16         inf           1.00
# 11      0.16         inf           1.00
# 12      0.16         inf           1.00
# 13      0.16         inf           1.00
# 14      0.12         inf           0.75
# 15      0.12         inf           0.75
# 16      0.12         inf           0.75
# 17      0.16         inf           1.00
# 18      0.12         inf           0.75
# 19      0.16         inf           1.00
#
# --- Store: Walmart ---
# Brute Force Time: 0.0004 seconds
# Frequent Itemsets (Brute Force): [({'BBQ Grill'}, 0.2), ({'Vacuum Cleaner'}, 0.2), ({'Microwave Oven'}, 0.2), ({'Blender'}, 0.4), ({'Towel Set'}, 0.2), ({'Camping Tent'}, 0.2), ({'Yoga Mat'}, 0.2), ({'Office Chair'}, 0.2), ({'Electric Kettle'}, 0.2), ({'Air Fryer'}, 0.2), ({'BBQ Grill', 'Camping Tent'}, 0.2), ({'Vacuum Cleaner', 'Air Fryer'}, 0.2), ({'Microwave Oven', 'Electric Kettle'}, 0.2), ({'Blender', 'Towel Set'}, 0.2), ({'Blender', 'Yoga Mat'}, 0.2), ({'Blender', 'Office Chair'}, 0.2), ({'Towel Set', 'Yoga Mat'}, 0.2), ({'Blender', 'Towel Set', 'Yoga Mat'}, 0.2)]
# Association Rules (Brute Force): [({'Camping Tent'}, 'BBQ Grill', 1.0), ({'BBQ Grill'}, 'Camping Tent', 1.0), ({'Air Fryer'}, 'Vacuum Cleaner', 1.0), ({'Vacuum Cleaner'}, 'Air Fryer', 1.0), ({'Electric Kettle'}, 'Microwave Oven', 1.0), ({'Microwave Oven'}, 'Electric Kettle', 1.0), ({'Towel Set'}, 'Blender', 1.0), ({'Yoga Mat'}, 'Blender', 1.0), ({'Office Chair'}, 'Blender', 1.0), ({'Yoga Mat'}, 'Towel Set', 1.0), ({'Towel Set'}, 'Yoga Mat', 1.0), ({'Towel Set', 'Yoga Mat'}, 'Blender', 1.0), ({'Blender', 'Yoga Mat'}, 'Towel Set', 1.0), ({'Blender', 'Towel Set'}, 'Yoga Mat', 1.0)]
# Apriori Time: 0.0095 seconds
# Frequent Itemsets (Apriori):
#     support                           itemsets
# 0       0.2                        (BBQ Grill)
# 1       0.2                   (Vacuum Cleaner)
# 2       0.2                   (Microwave Oven)
# 3       0.4                          (Blender)
# 4       0.2                        (Towel Set)
# 5       0.2                     (Camping Tent)
# 6       0.2                         (Yoga Mat)
# 7       0.2                     (Office Chair)
# 8       0.2                  (Electric Kettle)
# 9       0.2                        (Air Fryer)
# 10      0.2          (BBQ Grill, Camping Tent)
# 11      0.2        (Vacuum Cleaner, Air Fryer)
# 12      0.2  (Microwave Oven, Electric Kettle)
# 13      0.2               (Blender, Towel Set)
# 14      0.2                (Blender, Yoga Mat)
# 15      0.2            (Blender, Office Chair)
# 16      0.2              (Towel Set, Yoga Mat)
# 17      0.2     (Blender, Towel Set, Yoga Mat)
# Association Rules (Apriori):
#               antecedents           consequents  antecedent support  \
# 0             (BBQ Grill)        (Camping Tent)                 0.2
# 1          (Camping Tent)           (BBQ Grill)                 0.2
# 2        (Vacuum Cleaner)           (Air Fryer)                 0.2
# 3             (Air Fryer)      (Vacuum Cleaner)                 0.2
# 4        (Microwave Oven)     (Electric Kettle)                 0.2
# 5       (Electric Kettle)      (Microwave Oven)                 0.2
# 6             (Towel Set)             (Blender)                 0.2
# 7              (Yoga Mat)             (Blender)                 0.2
# 8          (Office Chair)             (Blender)                 0.2
# 9             (Towel Set)            (Yoga Mat)                 0.2
# 10             (Yoga Mat)           (Towel Set)                 0.2
# 11   (Blender, Towel Set)            (Yoga Mat)                 0.2
# 12    (Blender, Yoga Mat)           (Towel Set)                 0.2
# 13  (Towel Set, Yoga Mat)             (Blender)                 0.2
# 14            (Towel Set)   (Blender, Yoga Mat)                 0.2
# 15             (Yoga Mat)  (Blender, Towel Set)                 0.2
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  0.2      0.2         1.0   5.0      0.16         inf
# 1                  0.2      0.2         1.0   5.0      0.16         inf
# 2                  0.2      0.2         1.0   5.0      0.16         inf
# 3                  0.2      0.2         1.0   5.0      0.16         inf
# 4                  0.2      0.2         1.0   5.0      0.16         inf
# 5                  0.2      0.2         1.0   5.0      0.16         inf
# 6                  0.4      0.2         1.0   2.5      0.12         inf
# 7                  0.4      0.2         1.0   2.5      0.12         inf
# 8                  0.4      0.2         1.0   2.5      0.12         inf
# 9                  0.2      0.2         1.0   5.0      0.16         inf
# 10                 0.2      0.2         1.0   5.0      0.16         inf
# 11                 0.2      0.2         1.0   5.0      0.16         inf
# 12                 0.2      0.2         1.0   5.0      0.16         inf
# 13                 0.4      0.2         1.0   2.5      0.12         inf
# 14                 0.2      0.2         1.0   5.0      0.16         inf
# 15                 0.2      0.2         1.0   5.0      0.16         inf
#
#     zhangs_metric
# 0            1.00
# 1            1.00
# 2            1.00
# 3            1.00
# 4            1.00
# 5            1.00
# 6            0.75
# 7            0.75
# 8            0.75
# 9            1.00
# 10           1.00
# 11           1.00
# 12           1.00
# 13           0.75
# 14           1.00
# 15           1.00
# FP-Growth Time: 0.0073 seconds
# Frequent Itemsets (FP-Growth):
#     support                           itemsets
# 0       0.2                     (Camping Tent)
# 1       0.2                        (BBQ Grill)
# 2       0.2                        (Air Fryer)
# 3       0.2                   (Vacuum Cleaner)
# 4       0.4                          (Blender)
# 5       0.2                         (Yoga Mat)
# 6       0.2                        (Towel Set)
# 7       0.2                  (Electric Kettle)
# 8       0.2                   (Microwave Oven)
# 9       0.2                     (Office Chair)
# 10      0.2          (BBQ Grill, Camping Tent)
# 11      0.2        (Vacuum Cleaner, Air Fryer)
# 12      0.2                (Blender, Yoga Mat)
# 13      0.2              (Towel Set, Yoga Mat)
# 14      0.2               (Blender, Towel Set)
# 15      0.2     (Blender, Towel Set, Yoga Mat)
# 16      0.2  (Microwave Oven, Electric Kettle)
# 17      0.2            (Blender, Office Chair)
# Association Rules (FP-Growth):
#               antecedents           consequents  antecedent support  \
# 0             (BBQ Grill)        (Camping Tent)                 0.2
# 1          (Camping Tent)           (BBQ Grill)                 0.2
# 2        (Vacuum Cleaner)           (Air Fryer)                 0.2
# 3             (Air Fryer)      (Vacuum Cleaner)                 0.2
# 4              (Yoga Mat)             (Blender)                 0.2
# 5             (Towel Set)            (Yoga Mat)                 0.2
# 6              (Yoga Mat)           (Towel Set)                 0.2
# 7             (Towel Set)             (Blender)                 0.2
# 8    (Blender, Towel Set)            (Yoga Mat)                 0.2
# 9     (Blender, Yoga Mat)           (Towel Set)                 0.2
# 10  (Towel Set, Yoga Mat)             (Blender)                 0.2
# 11            (Towel Set)   (Blender, Yoga Mat)                 0.2
# 12             (Yoga Mat)  (Blender, Towel Set)                 0.2
# 13       (Microwave Oven)     (Electric Kettle)                 0.2
# 14      (Electric Kettle)      (Microwave Oven)                 0.2
# 15         (Office Chair)             (Blender)                 0.2
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  0.2      0.2         1.0   5.0      0.16         inf
# 1                  0.2      0.2         1.0   5.0      0.16         inf
# 2                  0.2      0.2         1.0   5.0      0.16         inf
# 3                  0.2      0.2         1.0   5.0      0.16         inf
# 4                  0.4      0.2         1.0   2.5      0.12         inf
# 5                  0.2      0.2         1.0   5.0      0.16         inf
# 6                  0.2      0.2         1.0   5.0      0.16         inf
# 7                  0.4      0.2         1.0   2.5      0.12         inf
# 8                  0.2      0.2         1.0   5.0      0.16         inf
# 9                  0.2      0.2         1.0   5.0      0.16         inf
# 10                 0.4      0.2         1.0   2.5      0.12         inf
# 11                 0.2      0.2         1.0   5.0      0.16         inf
# 12                 0.2      0.2         1.0   5.0      0.16         inf
# 13                 0.2      0.2         1.0   5.0      0.16         inf
# 14                 0.2      0.2         1.0   5.0      0.16         inf
# 15                 0.4      0.2         1.0   2.5      0.12         inf
#
#     zhangs_metric
# 0            1.00
# 1            1.00
# 2            1.00
# 3            1.00
# 4            0.75
# 5            1.00
# 6            1.00
# 7            0.75
# 8            1.00
# 9            1.00
# 10           0.75
# 11           1.00
# 12           1.00
# 13           1.00
# 14           1.00
# 15           0.75

# %%
pip install pyarrow==14.0.1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: pyarrow==14.0.1 in /usr/local/lib/python3.10/dist-packages (14.0.1)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow==14.0.1) (1.26.4)

# %%
from itertools import combinations

# Define items for Nike, Amazon, and Walmart
nike_items = [
    "Running Shoes", "Soccer Shoes", "Socks", "Swimming Shirt", "Dry Fit V-Neck",
    "Rash Guard", "Sweatshirts", "Hoodies", "Tech Pants", "Modern Pants"
]

amazon_items = [
    "Laptop", "Headphones", "Mouse", "Keyboard", "Monitor",
    "Smartphone", "Tablet", "Charger", "USB Cable", "HDMI Cable"
]

walmart_items = [
    "Milk", "Bread", "Eggs", "Butter", "Cheese",
    "Cereal", "Chicken", "Beef", "Pasta", "Rice"
]

# Transactions for Nike
nike_transactions = [
    ["Running Shoes", "Socks", "Sweatshirts"],
    ["Soccer Shoes", "Socks"],
    ["Swimming Shirt", "Dry Fit V-Neck"],
    ["Rash Guard", "Hoodies", "Tech Pants"],
    ["Modern Pants", "Sweatshirts"],
    ["Running Shoes", "Swimming Shirt"],
    ["Dry Fit V-Neck", "Soccer Shoes"],
    ["Socks", "Sweatshirts", "Tech Pants"],
    ["Hoodies", "Rash Guard", "Modern Pants"],
    ["Socks", "Swimming Shirt"],
    ["Tech Pants", "Sweatshirts"],
    ["Running Shoes", "Soccer Shoes", "Hoodies"]
]

# Transactions for Amazon
amazon_transactions = [
    ["Laptop", "Headphones", "Mouse"],
    ["Smartphone", "Charger"],
    ["Tablet", "Keyboard"],
    ["Monitor", "HDMI Cable", "USB Cable"],
    ["Laptop", "Charger", "USB Cable"],
    ["Smartphone", "Headphones"],
    ["Mouse", "Keyboard"],
    ["Tablet", "USB Cable"],
    ["Monitor", "Laptop"],
    ["Smartphone", "HDMI Cable"],
    ["Charger", "USB Cable"],
    ["Laptop", "Smartphone", "Charger"],
]

# Transactions for Walmart
walmart_transactions = [
    ["Milk", "Bread", "Eggs"],
    ["Chicken", "Rice"],
    ["Pasta", "Butter"],
    ["Beef", "Cheese", "Eggs"],
    ["Milk", "Cereal", "Bread"],
    ["Chicken", "Pasta"],
    ["Beef", "Rice"],
    ["Butter", "Eggs"],
    ["Cereal", "Milk", "Bread"],
    ["Pasta", "Butter"],
    ["Chicken", "Rice"],
    ["Cheese", "Eggs"],
]

# Minimum support and confidence
min_support = 2
min_confidence = 0.7

def calculate_support(itemset, transactions):
    count = 0
    for transaction in transactions:
        if itemset.issubset(transaction):
            count += 1
    return count

def find_frequent_itemsets(items, transactions, size, min_support):
    itemsets = [set(combo) for combo in combinations(items, size)]
    frequent_itemsets = []
    for itemset in itemsets:
        support = calculate_support(itemset, transactions)
        if support >= min_support:
            frequent_itemsets.append((itemset, support))
    return frequent_itemsets

def brute_force_frequent_itemsets(items, transactions, min_support):
    k = 1
    frequent_itemsets = []
    while True:
        current_frequent_itemsets = find_frequent_itemsets(items, transactions, k, min_support)
        if len(current_frequent_itemsets) == 0:
            break
        frequent_itemsets.extend(current_frequent_itemsets)
        k += 1
    return frequent_itemsets

def generate_association_rules(frequent_itemsets, transactions, min_support, min_confidence):
    rules = []
    transaction_count = len(transactions)

    def calculate_support(itemset):
        count = sum(1 for transaction in transactions if itemset.issubset(transaction))
        return count / transaction_count

    for itemset, support in frequent_itemsets:
        if len(itemset) < 2:
            continue

        for i in range(1, len(itemset)):
            for antecedent in combinations(itemset, i):
                antecedent = set(antecedent)
                consequent = itemset - antecedent

                antecedent_support = calculate_support(antecedent)
                confidence = support / antecedent_support if antecedent_support > 0 else 0

                if confidence >= min_confidence:
                    rules.append([antecedent, consequent, support, confidence])

    return rules

# Function to process Nike, Amazon, and Walmart
def process_transactions(transactions, items, store_name):
    print(f"\n--- {store_name} ---")
    frequent_itemsets = brute_force_frequent_itemsets(items, [set(t) for t in transactions], min_support)
    association_rules = generate_association_rules(frequent_itemsets, [set(t) for t in transactions], min_support, min_confidence)

    print("Frequent Itemsets:")
    for itemset, support in frequent_itemsets:
        print(f"Itemset: {itemset}, Support: {support}")

    print("\nAssociation Rules:")
    for antecedent, consequent, support, confidence in association_rules:
        print(f"Rule: {antecedent} -> {consequent}, Support={support}, Confidence={confidence}")

# Process transactions for each store
process_transactions(nike_transactions, nike_items, "Nike")
process_transactions(amazon_transactions, amazon_items, "Amazon")
process_transactions(walmart_transactions, walmart_items, "Walmart")
# Out:
# --- Nike ---
# Frequent Itemsets:
# Itemset: {'Running Shoes'}, Support: 3
# Itemset: {'Soccer Shoes'}, Support: 3
# Itemset: {'Socks'}, Support: 4
# Itemset: {'Swimming Shirt'}, Support: 3
# Itemset: {'Dry Fit V-Neck'}, Support: 2
# Itemset: {'Rash Guard'}, Support: 2
# Itemset: {'Sweatshirts'}, Support: 4
# Itemset: {'Hoodies'}, Support: 3
# Itemset: {'Tech Pants'}, Support: 3
# Itemset: {'Modern Pants'}, Support: 2
# Itemset: {'Socks', 'Sweatshirts'}, Support: 2
# Itemset: {'Hoodies', 'Rash Guard'}, Support: 2
# Itemset: {'Tech Pants', 'Sweatshirts'}, Support: 2
#
# Association Rules:
# Rule: {'Socks'} -> {'Sweatshirts'}, Support=2, Confidence=6.0
# Rule: {'Sweatshirts'} -> {'Socks'}, Support=2, Confidence=6.0
# Rule: {'Hoodies'} -> {'Rash Guard'}, Support=2, Confidence=8.0
# Rule: {'Rash Guard'} -> {'Hoodies'}, Support=2, Confidence=12.0
# Rule: {'Tech Pants'} -> {'Sweatshirts'}, Support=2, Confidence=8.0
# Rule: {'Sweatshirts'} -> {'Tech Pants'}, Support=2, Confidence=6.0
#
# --- Amazon ---
# Frequent Itemsets:
# Itemset: {'Laptop'}, Support: 4
# Itemset: {'Headphones'}, Support: 2
# Itemset: {'Mouse'}, Support: 2
# Itemset: {'Keyboard'}, Support: 2
# Itemset: {'Monitor'}, Support: 2
# Itemset: {'Smartphone'}, Support: 4
# Itemset: {'Tablet'}, Support: 2
# Itemset: {'Charger'}, Support: 4
# Itemset: {'USB Cable'}, Support: 4
# Itemset: {'HDMI Cable'}, Support: 2
# Itemset: {'Laptop', 'Charger'}, Support: 2
# Itemset: {'Charger', 'Smartphone'}, Support: 2
# Itemset: {'USB Cable', 'Charger'}, Support: 2
#
# Association Rules:
# Rule: {'Laptop'} -> {'Charger'}, Support=2, Confidence=6.0
# Rule: {'Charger'} -> {'Laptop'}, Support=2, Confidence=6.0
# Rule: {'Charger'} -> {'Smartphone'}, Support=2, Confidence=6.0
# Rule: {'Smartphone'} -> {'Charger'}, Support=2, Confidence=6.0
# Rule: {'USB Cable'} -> {'Charger'}, Support=2, Confidence=6.0
# Rule: {'Charger'} -> {'USB Cable'}, Support=2, Confidence=6.0
#
# --- Walmart ---
# Frequent Itemsets:
# Itemset: {'Milk'}, Support: 3
# Itemset: {'Bread'}, Support: 3
# Itemset: {'Eggs'}, Support: 4
# Itemset: {'Butter'}, Support: 3
# Itemset: {'Cheese'}, Support: 2
# Itemset: {'Cereal'}, Support: 2
# Itemset: {'Chicken'}, Support: 3
# Itemset: {'Beef'}, Support: 2
# Itemset: {'Pasta'}, Support: 3
# Itemset: {'Rice'}, Support: 3
# Itemset: {'Bread', 'Milk'}, Support: 3
# Itemset: {'Cereal', 'Milk'}, Support: 2
# Itemset: {'Cereal', 'Bread'}, Support: 2
# Itemset: {'Cheese', 'Eggs'}, Support: 2
# Itemset: {'Butter', 'Pasta'}, Support: 2
# Itemset: {'Chicken', 'Rice'}, Support: 2
# Itemset: {'Bread', 'Cereal', 'Milk'}, Support: 2
#
# Association Rules:
# Rule: {'Bread'} -> {'Milk'}, Support=3, Confidence=12.0
# Rule: {'Milk'} -> {'Bread'}, Support=3, Confidence=12.0
# Rule: {'Cereal'} -> {'Milk'}, Support=2, Confidence=12.0
# Rule: {'Milk'} -> {'Cereal'}, Support=2, Confidence=8.0
# Rule: {'Cereal'} -> {'Bread'}, Support=2, Confidence=12.0
# Rule: {'Bread'} -> {'Cereal'}, Support=2, Confidence=8.0
# Rule: {'Cheese'} -> {'Eggs'}, Support=2, Confidence=12.0
# Rule: {'Eggs'} -> {'Cheese'}, Support=2, Confidence=6.0
# Rule: {'Butter'} -> {'Pasta'}, Support=2, Confidence=8.0
# Rule: {'Pasta'} -> {'Butter'}, Support=2, Confidence=8.0
# Rule: {'Chicken'} -> {'Rice'}, Support=2, Confidence=8.0
# Rule: {'Rice'} -> {'Chicken'}, Support=2, Confidence=8.0
# Rule: {'Bread'} -> {'Cereal', 'Milk'}, Support=2, Confidence=8.0
# Rule: {'Cereal'} -> {'Milk', 'Bread'}, Support=2, Confidence=12.0
# Rule: {'Milk'} -> {'Cereal', 'Bread'}, Support=2, Confidence=8.0
# Rule: {'Cereal', 'Bread'} -> {'Milk'}, Support=2, Confidence=12.0
# Rule: {'Milk', 'Bread'} -> {'Cereal'}, Support=2, Confidence=8.0
# Rule: {'Cereal', 'Milk'} -> {'Bread'}, Support=2, Confidence=12.0
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from itertools import combinations

# Define items for Nike, Amazon, and Walmart
nike_items = [
    "Running Shoes", "Soccer Shoes", "Socks", "Swimming Shirt", "Dry Fit V-Neck",
    "Rash Guard", "Sweatshirts", "Hoodies", "Tech Pants", "Modern Pants"
]

amazon_items = [
    "Laptop", "Headphones", "Mouse", "Keyboard", "Monitor",
    "Smartphone", "Tablet", "Charger", "USB Cable", "HDMI Cable"
]

walmart_items = [
    "Milk", "Bread", "Eggs", "Butter", "Cheese",
    "Cereal", "Chicken", "Beef", "Pasta", "Rice"
]

# Transactions for Nike
nike_transactions = [
    ["Running Shoes", "Socks", "Sweatshirts"],
    ["Soccer Shoes", "Socks"],
    ["Swimming Shirt", "Dry Fit V-Neck"],
    ["Rash Guard", "Hoodies", "Tech Pants"],
    ["Modern Pants", "Sweatshirts"],
    ["Running Shoes", "Swimming Shirt"],
    ["Dry Fit V-Neck", "Soccer Shoes"],
    ["Socks", "Sweatshirts", "Tech Pants"],
    ["Hoodies", "Rash Guard", "Modern Pants"],
    ["Socks", "Swimming Shirt"],
    ["Tech Pants", "Sweatshirts"],
    ["Running Shoes", "Soccer Shoes", "Hoodies"]
]

# Transactions for Amazon
amazon_transactions = [
    ["Laptop", "Headphones", "Mouse"],
    ["Smartphone", "Charger"],
    ["Tablet", "Keyboard"],
    ["Monitor", "HDMI Cable", "USB Cable"],
    ["Laptop", "Charger", "USB Cable"],
    ["Smartphone", "Headphones"],
    ["Mouse", "Keyboard"],
    ["Tablet", "USB Cable"],
    ["Monitor", "Laptop"],
    ["Smartphone", "HDMI Cable"],
    ["Charger", "USB Cable"],
    ["Laptop", "Smartphone", "Charger"],
]

# Transactions for Walmart
walmart_transactions = [
    ["Milk", "Bread", "Eggs"],
    ["Chicken", "Rice"],
    ["Pasta", "Butter"],
    ["Beef", "Cheese", "Eggs"],
    ["Milk", "Cereal", "Bread"],
    ["Chicken", "Pasta"],
    ["Beef", "Rice"],
    ["Butter", "Eggs"],
    ["Cereal", "Milk", "Bread"],
    ["Pasta", "Butter"],
    ["Chicken", "Rice"],
    ["Cheese", "Eggs"],
]

# Minimum support and confidence
min_support = 2
min_confidence = 0.7

def calculate_support(itemset, transactions):
    count = 0
    for transaction in transactions:
        if itemset.issubset(transaction):
            count += 1
    return count

def find_frequent_itemsets(items, transactions, size, min_support):
    itemsets = [set(combo) for combo in combinations(items, size)]
    frequent_itemsets = []
    for itemset in itemsets:
        support = calculate_support(itemset, transactions)
        if support >= min_support:
            frequent_itemsets.append((itemset, support))
    return frequent_itemsets

def brute_force_frequent_itemsets(items, transactions, min_support):
    k = 1
    frequent_itemsets = []
    while True:
        current_frequent_itemsets = find_frequent_itemsets(items, transactions, k, min_support)
        if len(current_frequent_itemsets) == 0:
            break
        frequent_itemsets.extend(current_frequent_itemsets)
        k += 1
    return frequent_itemsets

def generate_association_rules(frequent_itemsets, transactions, min_support, min_confidence):
    rules = []
    transaction_count = len(transactions)

    def calculate_support(itemset):
        count = sum(1 for transaction in transactions if itemset.issubset(transaction))
        return count / transaction_count

    for itemset, support in frequent_itemsets:
        if len(itemset) < 2:
            continue

        for i in range(1, len(itemset)):
            for antecedent in combinations(itemset, i):
                antecedent = set(antecedent)
                consequent = itemset - antecedent

                antecedent_support = calculate_support(antecedent)
                confidence = support / antecedent_support if antecedent_support > 0 else 0

                if confidence >= min_confidence:
                    rules.append([antecedent, consequent, support, confidence])

    return rules

# Function to process Nike, Amazon, and Walmart
def process_transactions(transactions, items, store_name):
    print(f"\n--- {store_name} ---")
    frequent_itemsets = brute_force_frequent_itemsets(items, [set(t) for t in transactions], min_support)
    association_rules = generate_association_rules(frequent_itemsets, [set(t) for t in transactions], min_support, min_confidence)

    print("Frequent Itemsets:")
    for itemset, support in frequent_itemsets:
        print(f"Itemset: {itemset}, Support: {support}")

    print("\nAssociation Rules:")
    for antecedent, consequent, support, confidence in association_rules:
        print(f"Rule: {antecedent} -> {consequent}, Support={support}, Confidence={confidence}")

# Process transactions for each store
process_transactions(nike_transactions, nike_items, "Nike")
process_transactions(amazon_transactions, amazon_items, "Amazon")
process_transactions(walmart_transactions, walmart_items, "Walmart")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.10/dist-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Enter minimum support (e.g., 0.2): 0.2
# Enter minimum confidence (e.g., 0.7): 0.8
#
# --- Nike ---
# Brute Force Time: 0.0006 seconds
# Frequent Itemsets (Brute Force): [({'Running Shoes'}, 0.2), ({'Soccer Shoes'}, 0.2), ({'Socks'}, 0.4), ({'Swimming Shirt'}, 0.2), ({'Dry Fit V-Neck'}, 0.2), ({'Rash Guard'}, 0.2), ({'Sweatshirts'}, 0.4), ({'Hoodies'}, 0.2), ({'Tech Pants'}, 0.2), ({'Modern Pants'}, 0.2), ({'Running Shoes', 'Socks'}, 0.2), ({'Running Shoes', 'Sweatshirts'}, 0.2), ({'Socks', 'Soccer Shoes'}, 0.2), ({'Socks', 'Sweatshirts'}, 0.2), ({'Swimming Shirt', 'Dry Fit V-Neck'}, 0.2), ({'Hoodies', 'Rash Guard'}, 0.2), ({'Tech Pants', 'Rash Guard'}, 0.2), ({'Modern Pants', 'Sweatshirts'}, 0.2), ({'Hoodies', 'Tech Pants'}, 0.2), ({'Running Shoes', 'Socks', 'Sweatshirts'}, 0.2), ({'Hoodies', 'Tech Pants', 'Rash Guard'}, 0.2)]
# Association Rules (Brute Force): [({'Running Shoes'}, 'Socks', 1.0), ({'Running Shoes'}, 'Sweatshirts', 1.0), ({'Soccer Shoes'}, 'Socks', 1.0), ({'Dry Fit V-Neck'}, 'Swimming Shirt', 1.0), ({'Swimming Shirt'}, 'Dry Fit V-Neck', 1.0), ({'Rash Guard'}, 'Hoodies', 1.0), ({'Hoodies'}, 'Rash Guard', 1.0), ({'Rash Guard'}, 'Tech Pants', 1.0), ({'Tech Pants'}, 'Rash Guard', 1.0), ({'Modern Pants'}, 'Sweatshirts', 1.0), ({'Tech Pants'}, 'Hoodies', 1.0), ({'Hoodies'}, 'Tech Pants', 1.0), ({'Socks', 'Sweatshirts'}, 'Running Shoes', 1.0), ({'Running Shoes', 'Sweatshirts'}, 'Socks', 1.0), ({'Running Shoes', 'Socks'}, 'Sweatshirts', 1.0), ({'Tech Pants', 'Rash Guard'}, 'Hoodies', 1.0), ({'Hoodies', 'Rash Guard'}, 'Tech Pants', 1.0), ({'Hoodies', 'Tech Pants'}, 'Rash Guard', 1.0)]
# Apriori Time: 0.0141 seconds
# Frequent Itemsets (Apriori):
#     support                             itemsets
# 0       0.2                      (Running Shoes)
# 1       0.2                       (Soccer Shoes)
# 2       0.4                              (Socks)
# 3       0.2                     (Swimming Shirt)
# 4       0.2                     (Dry Fit V-Neck)
# 5       0.2                         (Rash Guard)
# 6       0.4                        (Sweatshirts)
# 7       0.2                            (Hoodies)
# 8       0.2                         (Tech Pants)
# 9       0.2                       (Modern Pants)
# 10      0.2               (Running Shoes, Socks)
# 11      0.2         (Running Shoes, Sweatshirts)
# 12      0.2                (Socks, Soccer Shoes)
# 13      0.2                 (Socks, Sweatshirts)
# 14      0.2     (Swimming Shirt, Dry Fit V-Neck)
# 15      0.2                (Hoodies, Rash Guard)
# 16      0.2             (Tech Pants, Rash Guard)
# 17      0.2          (Modern Pants, Sweatshirts)
# 18      0.2                (Hoodies, Tech Pants)
# 19      0.2  (Running Shoes, Socks, Sweatshirts)
# 20      0.2    (Hoodies, Tech Pants, Rash Guard)
# Association Rules (Apriori):
#                      antecedents               consequents  \
# 0                (Running Shoes)                   (Socks)
# 1                (Running Shoes)             (Sweatshirts)
# 2                 (Soccer Shoes)                   (Socks)
# 3               (Swimming Shirt)          (Dry Fit V-Neck)
# 4               (Dry Fit V-Neck)          (Swimming Shirt)
# 5                      (Hoodies)              (Rash Guard)
# 6                   (Rash Guard)                 (Hoodies)
# 7                   (Tech Pants)              (Rash Guard)
# 8                   (Rash Guard)              (Tech Pants)
# 9                 (Modern Pants)             (Sweatshirts)
# 10                     (Hoodies)              (Tech Pants)
# 11                  (Tech Pants)                 (Hoodies)
# 12        (Running Shoes, Socks)             (Sweatshirts)
# 13  (Running Shoes, Sweatshirts)                   (Socks)
# 14          (Socks, Sweatshirts)           (Running Shoes)
# 15               (Running Shoes)      (Socks, Sweatshirts)
# 16         (Hoodies, Tech Pants)              (Rash Guard)
# 17         (Hoodies, Rash Guard)              (Tech Pants)
# 18      (Tech Pants, Rash Guard)                 (Hoodies)
# 19                     (Hoodies)  (Tech Pants, Rash Guard)
# 20                  (Tech Pants)     (Hoodies, Rash Guard)
# 21                  (Rash Guard)     (Hoodies, Tech Pants)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 0                  0.2                 0.4      0.2         1.0   2.5
# 1                  0.2                 0.4      0.2         1.0   2.5
# 2                  0.2                 0.4      0.2         1.0   2.5
# 3                  0.2                 0.2      0.2         1.0   5.0
# 4                  0.2                 0.2      0.2         1.0   5.0
# 5                  0.2                 0.2      0.2         1.0   5.0
# 6                  0.2                 0.2      0.2         1.0   5.0
# 7                  0.2                 0.2      0.2         1.0   5.0
# 8                  0.2                 0.2      0.2         1.0   5.0
# 9                  0.2                 0.4      0.2         1.0   2.5
# 10                 0.2                 0.2      0.2         1.0   5.0
# 11                 0.2                 0.2      0.2         1.0   5.0
# 12                 0.2                 0.4      0.2         1.0   2.5
# 13                 0.2                 0.4      0.2         1.0   2.5
# 14                 0.2                 0.2      0.2         1.0   5.0
# 15                 0.2                 0.2      0.2         1.0   5.0
# 16                 0.2                 0.2      0.2         1.0   5.0
# 17                 0.2                 0.2      0.2         1.0   5.0
# 18                 0.2                 0.2      0.2         1.0   5.0
# 19                 0.2                 0.2      0.2         1.0   5.0
# 20                 0.2                 0.2      0.2         1.0   5.0
# 21                 0.2                 0.2      0.2         1.0   5.0
#
#     leverage  conviction  zhangs_metric
# 0       0.12         inf           0.75
# 1       0.12         inf           0.75
# 2       0.12         inf           0.75
# 3       0.16         inf           1.00
# 4       0.16         inf           1.00
# 5       0.16         inf           1.00
# 6       0.16         inf           1.00
# 7       0.16         inf           1.00
# 8       0.16         inf           1.00
# 9       0.12         inf           0.75
# 10      0.16         inf           1.00
# 11      0.16         inf           1.00
# 12      0.12         inf           0.75
# 13      0.12         inf           0.75
# 14      0.16         inf           1.00
# 15      0.16         inf           1.00
# 16      0.16         inf           1.00
# 17      0.16         inf           1.00
# 18      0.16         inf           1.00
# 19      0.16         inf           1.00
# 20      0.16         inf           1.00
# 21      0.16         inf           1.00
# FP-Growth Time: 0.0052 seconds
# Frequent Itemsets (FP-Growth):
#     support                             itemsets
# 0       0.4                        (Sweatshirts)
# 1       0.4                              (Socks)
# 2       0.2                      (Running Shoes)
# 3       0.2                       (Soccer Shoes)
# 4       0.2                     (Dry Fit V-Neck)
# 5       0.2                     (Swimming Shirt)
# 6       0.2                         (Tech Pants)
# 7       0.2                            (Hoodies)
# 8       0.2                         (Rash Guard)
# 9       0.2                       (Modern Pants)
# 10      0.2                 (Socks, Sweatshirts)
# 11      0.2               (Running Shoes, Socks)
# 12      0.2         (Running Shoes, Sweatshirts)
# 13      0.2  (Running Shoes, Socks, Sweatshirts)
# 14      0.2                (Socks, Soccer Shoes)
# 15      0.2     (Swimming Shirt, Dry Fit V-Neck)
# 16      0.2                (Hoodies, Tech Pants)
# 17      0.2                (Hoodies, Rash Guard)
# 18      0.2             (Tech Pants, Rash Guard)
# 19      0.2    (Hoodies, Tech Pants, Rash Guard)
# 20      0.2          (Modern Pants, Sweatshirts)
# Association Rules (FP-Growth):
#                      antecedents               consequents  \
# 0                (Running Shoes)                   (Socks)
# 1                (Running Shoes)             (Sweatshirts)
# 2         (Running Shoes, Socks)             (Sweatshirts)
# 3   (Running Shoes, Sweatshirts)                   (Socks)
# 4           (Socks, Sweatshirts)           (Running Shoes)
# 5                (Running Shoes)      (Socks, Sweatshirts)
# 6                 (Soccer Shoes)                   (Socks)
# 7               (Swimming Shirt)          (Dry Fit V-Neck)
# 8               (Dry Fit V-Neck)          (Swimming Shirt)
# 9                      (Hoodies)              (Tech Pants)
# 10                  (Tech Pants)                 (Hoodies)
# 11                     (Hoodies)              (Rash Guard)
# 12                  (Rash Guard)                 (Hoodies)
# 13                  (Tech Pants)              (Rash Guard)
# 14                  (Rash Guard)              (Tech Pants)
# 15         (Hoodies, Tech Pants)              (Rash Guard)
# 16         (Hoodies, Rash Guard)              (Tech Pants)
# 17      (Tech Pants, Rash Guard)                 (Hoodies)
# 18                     (Hoodies)  (Tech Pants, Rash Guard)
# 19                  (Tech Pants)     (Hoodies, Rash Guard)
# 20                  (Rash Guard)     (Hoodies, Tech Pants)
# 21                (Modern Pants)             (Sweatshirts)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 0                  0.2                 0.4      0.2         1.0   2.5
# 1                  0.2                 0.4      0.2         1.0   2.5
# 2                  0.2                 0.4      0.2         1.0   2.5
# 3                  0.2                 0.4      0.2         1.0   2.5
# 4                  0.2                 0.2      0.2         1.0   5.0
# 5                  0.2                 0.2      0.2         1.0   5.0
# 6                  0.2                 0.4      0.2         1.0   2.5
# 7                  0.2                 0.2      0.2         1.0   5.0
# 8                  0.2                 0.2      0.2         1.0   5.0
# 9                  0.2                 0.2      0.2         1.0   5.0
# 10                 0.2                 0.2      0.2         1.0   5.0
# 11                 0.2                 0.2      0.2         1.0   5.0
# 12                 0.2                 0.2      0.2         1.0   5.0
# 13                 0.2                 0.2      0.2         1.0   5.0
# 14                 0.2                 0.2      0.2         1.0   5.0
# 15                 0.2                 0.2      0.2         1.0   5.0
# 16                 0.2                 0.2      0.2         1.0   5.0
# 17                 0.2                 0.2      0.2         1.0   5.0
# 18                 0.2                 0.2      0.2         1.0   5.0
# 19                 0.2                 0.2      0.2         1.0   5.0
# 20                 0.2                 0.2      0.2         1.0   5.0
# 21                 0.2                 0.4      0.2         1.0   2.5
#
#     leverage  conviction  zhangs_metric
# 0       0.12         inf           0.75
# 1       0.12         inf           0.75
# 2       0.12         inf           0.75
# 3       0.12         inf           0.75
# 4       0.16         inf           1.00
# 5       0.16         inf           1.00
# 6       0.12         inf           0.75
# 7       0.16         inf           1.00
# 8       0.16         inf           1.00
# 9       0.16         inf           1.00
# 10      0.16         inf           1.00
# 11      0.16         inf           1.00
# 12      0.16         inf           1.00
# 13      0.16         inf           1.00
# 14      0.16         inf           1.00
# 15      0.16         inf           1.00
# 16      0.16         inf           1.00
# 17      0.16         inf           1.00
# 18      0.16         inf           1.00
# 19      0.16         inf           1.00
# 20      0.16         inf           1.00
# 21      0.12         inf           0.75
#
# --- Amazon ---
# Brute Force Time: 0.0005 seconds
# Frequent Itemsets (Brute Force): [({'Laptop'}, 0.4), ({'Headphones'}, 0.2), ({'Mouse'}, 0.2), ({'Keyboard'}, 0.2), ({'Monitor'}, 0.2), ({'Smartphone'}, 0.2), ({'Tablet'}, 0.2), ({'Charger'}, 0.4), ({'USB Cable'}, 0.4), ({'HDMI Cable'}, 0.2), ({'Headphones', 'Laptop'}, 0.2), ({'Mouse', 'Laptop'}, 0.2), ({'Laptop', 'Charger'}, 0.2), ({'USB Cable', 'Laptop'}, 0.2), ({'Headphones', 'Mouse'}, 0.2), ({'Keyboard', 'Tablet'}, 0.2), ({'USB Cable', 'Monitor'}, 0.2), ({'HDMI Cable', 'Monitor'}, 0.2), ({'Charger', 'Smartphone'}, 0.2), ({'USB Cable', 'Charger'}, 0.2), ({'HDMI Cable', 'USB Cable'}, 0.2), ({'Headphones', 'Laptop', 'Mouse'}, 0.2), ({'USB Cable', 'Laptop', 'Charger'}, 0.2), ({'HDMI Cable', 'USB Cable', 'Monitor'}, 0.2)]
# Association Rules (Brute Force): [({'Headphones'}, 'Laptop', 1.0), ({'Mouse'}, 'Laptop', 1.0), ({'Mouse'}, 'Headphones', 1.0), ({'Headphones'}, 'Mouse', 1.0), ({'Tablet'}, 'Keyboard', 1.0), ({'Keyboard'}, 'Tablet', 1.0), ({'Monitor'}, 'USB Cable', 1.0), ({'Monitor'}, 'HDMI Cable', 1.0), ({'HDMI Cable'}, 'Monitor', 1.0), ({'Smartphone'}, 'Charger', 1.0), ({'HDMI Cable'}, 'USB Cable', 1.0), ({'Mouse', 'Laptop'}, 'Headphones', 1.0), ({'Headphones', 'Mouse'}, 'Laptop', 1.0), ({'Headphones', 'Laptop'}, 'Mouse', 1.0), ({'Laptop', 'Charger'}, 'USB Cable', 1.0), ({'USB Cable', 'Charger'}, 'Laptop', 1.0), ({'USB Cable', 'Laptop'}, 'Charger', 1.0), ({'USB Cable', 'Monitor'}, 'HDMI Cable', 1.0), ({'HDMI Cable', 'Monitor'}, 'USB Cable', 1.0), ({'USB Cable', 'HDMI Cable'}, 'Monitor', 1.0)]
# Apriori Time: 0.0085 seconds
# Frequent Itemsets (Apriori):
#     support                          itemsets
# 0       0.4                          (Laptop)
# 1       0.2                      (Headphones)
# 2       0.2                           (Mouse)
# 3       0.2                        (Keyboard)
# 4       0.2                         (Monitor)
# 5       0.2                      (Smartphone)
# 6       0.2                          (Tablet)
# 7       0.4                         (Charger)
# 8       0.4                       (USB Cable)
# 9       0.2                      (HDMI Cable)
# 10      0.2              (Headphones, Laptop)
# 11      0.2                   (Mouse, Laptop)
# 12      0.2                 (Laptop, Charger)
# 13      0.2               (USB Cable, Laptop)
# 14      0.2               (Headphones, Mouse)
# 15      0.2                (Keyboard, Tablet)
# 16      0.2              (USB Cable, Monitor)
# 17      0.2             (HDMI Cable, Monitor)
# 18      0.2             (Charger, Smartphone)
# 19      0.2              (USB Cable, Charger)
# 20      0.2           (HDMI Cable, USB Cable)
# 21      0.2       (Headphones, Laptop, Mouse)
# 22      0.2      (USB Cable, Laptop, Charger)
# 23      0.2  (HDMI Cable, USB Cable, Monitor)
# Association Rules (Apriori):
#                 antecedents              consequents  antecedent support  \
# 0              (Headphones)                 (Laptop)                 0.2
# 1                   (Mouse)                 (Laptop)                 0.2
# 2              (Headphones)                  (Mouse)                 0.2
# 3                   (Mouse)             (Headphones)                 0.2
# 4                (Keyboard)                 (Tablet)                 0.2
# 5                  (Tablet)               (Keyboard)                 0.2
# 6                 (Monitor)              (USB Cable)                 0.2
# 7              (HDMI Cable)                (Monitor)                 0.2
# 8                 (Monitor)             (HDMI Cable)                 0.2
# 9              (Smartphone)                (Charger)                 0.2
# 10             (HDMI Cable)              (USB Cable)                 0.2
# 11     (Headphones, Laptop)                  (Mouse)                 0.2
# 12      (Headphones, Mouse)                 (Laptop)                 0.2
# 13          (Mouse, Laptop)             (Headphones)                 0.2
# 14             (Headphones)          (Mouse, Laptop)                 0.2
# 15                  (Mouse)     (Headphones, Laptop)                 0.2
# 16      (USB Cable, Laptop)                (Charger)                 0.2
# 17     (USB Cable, Charger)                 (Laptop)                 0.2
# 18        (Laptop, Charger)              (USB Cable)                 0.2
# 19  (USB Cable, HDMI Cable)                (Monitor)                 0.2
# 20    (HDMI Cable, Monitor)              (USB Cable)                 0.2
# 21     (USB Cable, Monitor)             (HDMI Cable)                 0.2
# 22             (HDMI Cable)     (USB Cable, Monitor)                 0.2
# 23                (Monitor)  (USB Cable, HDMI Cable)                 0.2
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  0.4      0.2         1.0   2.5      0.12         inf
# 1                  0.4      0.2         1.0   2.5      0.12         inf
# 2                  0.2      0.2         1.0   5.0      0.16         inf
# 3                  0.2      0.2         1.0   5.0      0.16         inf
# 4                  0.2      0.2         1.0   5.0      0.16         inf
# 5                  0.2      0.2         1.0   5.0      0.16         inf
# 6                  0.4      0.2         1.0   2.5      0.12         inf
# 7                  0.2      0.2         1.0   5.0      0.16         inf
# 8                  0.2      0.2         1.0   5.0      0.16         inf
# 9                  0.4      0.2         1.0   2.5      0.12         inf
# 10                 0.4      0.2         1.0   2.5      0.12         inf
# 11                 0.2      0.2         1.0   5.0      0.16         inf
# 12                 0.4      0.2         1.0   2.5      0.12         inf
# 13                 0.2      0.2         1.0   5.0      0.16         inf
# 14                 0.2      0.2         1.0   5.0      0.16         inf
# 15                 0.2      0.2         1.0   5.0      0.16         inf
# 16                 0.4      0.2         1.0   2.5      0.12         inf
# 17                 0.4      0.2         1.0   2.5      0.12         inf
# 18                 0.4      0.2         1.0   2.5      0.12         inf
# 19                 0.2      0.2         1.0   5.0      0.16         inf
# 20                 0.4      0.2         1.0   2.5      0.12         inf
# 21                 0.2      0.2         1.0   5.0      0.16         inf
# 22                 0.2      0.2         1.0   5.0      0.16         inf
# 23                 0.2      0.2         1.0   5.0      0.16         inf
#
#     zhangs_metric
# 0            0.75
# 1            0.75
# 2            1.00
# 3            1.00
# 4            1.00
# 5            1.00
# 6            0.75
# 7            1.00
# 8            1.00
# 9            0.75
# 10           0.75
# 11           1.00
# 12           0.75
# 13           1.00
# 14           1.00
# 15           1.00
# 16           0.75
# 17           0.75
# 18           0.75
# 19           1.00
# 20           0.75
# 21           1.00
# 22           1.00
# 23           1.00
# FP-Growth Time: 0.0054 seconds
# Frequent Itemsets (FP-Growth):
#     support                          itemsets
# 0       0.4                          (Laptop)
# 1       0.2                           (Mouse)
# 2       0.2                      (Headphones)
# 3       0.4                         (Charger)
# 4       0.2                      (Smartphone)
# 5       0.2                          (Tablet)
# 6       0.2                        (Keyboard)
# 7       0.4                       (USB Cable)
# 8       0.2                      (HDMI Cable)
# 9       0.2                         (Monitor)
# 10      0.2                 (Laptop, Charger)
# 11      0.2               (USB Cable, Laptop)
# 12      0.2      (USB Cable, Laptop, Charger)
# 13      0.2                   (Mouse, Laptop)
# 14      0.2               (Headphones, Mouse)
# 15      0.2              (Headphones, Laptop)
# 16      0.2       (Headphones, Laptop, Mouse)
# 17      0.2              (USB Cable, Charger)
# 18      0.2             (Charger, Smartphone)
# 19      0.2                (Keyboard, Tablet)
# 20      0.2           (HDMI Cable, USB Cable)
# 21      0.2             (HDMI Cable, Monitor)
# 22      0.2              (USB Cable, Monitor)
# 23      0.2  (HDMI Cable, USB Cable, Monitor)
# Association Rules (FP-Growth):
#                 antecedents              consequents  antecedent support  \
# 0       (USB Cable, Laptop)                (Charger)                 0.2
# 1      (USB Cable, Charger)                 (Laptop)                 0.2
# 2         (Laptop, Charger)              (USB Cable)                 0.2
# 3                   (Mouse)                 (Laptop)                 0.2
# 4              (Headphones)                  (Mouse)                 0.2
# 5                   (Mouse)             (Headphones)                 0.2
# 6              (Headphones)                 (Laptop)                 0.2
# 7      (Headphones, Laptop)                  (Mouse)                 0.2
# 8       (Headphones, Mouse)                 (Laptop)                 0.2
# 9           (Mouse, Laptop)             (Headphones)                 0.2
# 10             (Headphones)          (Mouse, Laptop)                 0.2
# 11                  (Mouse)     (Headphones, Laptop)                 0.2
# 12             (Smartphone)                (Charger)                 0.2
# 13               (Keyboard)                 (Tablet)                 0.2
# 14                 (Tablet)               (Keyboard)                 0.2
# 15             (HDMI Cable)              (USB Cable)                 0.2
# 16             (HDMI Cable)                (Monitor)                 0.2
# 17                (Monitor)             (HDMI Cable)                 0.2
# 18                (Monitor)              (USB Cable)                 0.2
# 19  (USB Cable, HDMI Cable)                (Monitor)                 0.2
# 20    (HDMI Cable, Monitor)              (USB Cable)                 0.2
# 21     (USB Cable, Monitor)             (HDMI Cable)                 0.2
# 22             (HDMI Cable)     (USB Cable, Monitor)                 0.2
# 23                (Monitor)  (USB Cable, HDMI Cable)                 0.2
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  0.4      0.2         1.0   2.5      0.12         inf
# 1                  0.4      0.2         1.0   2.5      0.12         inf
# 2                  0.4      0.2         1.0   2.5      0.12         inf
# 3                  0.4      0.2         1.0   2.5      0.12         inf
# 4                  0.2      0.2         1.0   5.0      0.16         inf
# 5                  0.2      0.2         1.0   5.0      0.16         inf
# 6                  0.4      0.2         1.0   2.5      0.12         inf
# 7                  0.2      0.2         1.0   5.0      0.16         inf
# 8                  0.4      0.2         1.0   2.5      0.12         inf
# 9                  0.2      0.2         1.0   5.0      0.16         inf
# 10                 0.2      0.2         1.0   5.0      0.16         inf
# 11                 0.2      0.2         1.0   5.0      0.16         inf
# 12                 0.4      0.2         1.0   2.5      0.12         inf
# 13                 0.2      0.2         1.0   5.0      0.16         inf
# 14                 0.2      0.2         1.0   5.0      0.16         inf
# 15                 0.4      0.2         1.0   2.5      0.12         inf
# 16                 0.2      0.2         1.0   5.0      0.16         inf
# 17                 0.2      0.2         1.0   5.0      0.16         inf
# 18                 0.4      0.2         1.0   2.5      0.12         inf
# 19                 0.2      0.2         1.0   5.0      0.16         inf
# 20                 0.4      0.2         1.0   2.5      0.12         inf
# 21                 0.2      0.2         1.0   5.0      0.16         inf
# 22                 0.2      0.2         1.0   5.0      0.16         inf
# 23                 0.2      0.2         1.0   5.0      0.16         inf
#
#     zhangs_metric
# 0            0.75
# 1            0.75
# 2            0.75
# 3            0.75
# 4            1.00
# 5            1.00
# 6            0.75
# 7            1.00
# 8            0.75
# 9            1.00
# 10           1.00
# 11           1.00
# 12           0.75
# 13           1.00
# 14           1.00
# 15           0.75
# 16           1.00
# 17           1.00
# 18           0.75
# 19           1.00
# 20           0.75
# 21           1.00
# 22           1.00
# 23           1.00
#
# --- Walmart ---
# Brute Force Time: 0.0005 seconds
# Frequent Itemsets (Brute Force): [({'Milk'}, 0.4), ({'Bread'}, 0.4), ({'Eggs'}, 0.4), ({'Butter'}, 0.2), ({'Cheese'}, 0.2), ({'Cereal'}, 0.2), ({'Chicken'}, 0.2), ({'Beef'}, 0.2), ({'Pasta'}, 0.2), ({'Rice'}, 0.2), ({'Bread', 'Milk'}, 0.4), ({'Milk', 'Eggs'}, 0.2), ({'Cereal', 'Milk'}, 0.2), ({'Bread', 'Eggs'}, 0.2), ({'Cereal', 'Bread'}, 0.2), ({'Cheese', 'Eggs'}, 0.2), ({'Beef', 'Eggs'}, 0.2), ({'Butter', 'Pasta'}, 0.2), ({'Beef', 'Cheese'}, 0.2), ({'Chicken', 'Rice'}, 0.2), ({'Bread', 'Milk', 'Eggs'}, 0.2), ({'Bread', 'Cereal', 'Milk'}, 0.2), ({'Beef', 'Cheese', 'Eggs'}, 0.2)]
# Association Rules (Brute Force): [({'Milk'}, 'Bread', 1.0), ({'Bread'}, 'Milk', 1.0), ({'Cereal'}, 'Milk', 1.0), ({'Cereal'}, 'Bread', 1.0), ({'Cheese'}, 'Eggs', 1.0), ({'Beef'}, 'Eggs', 1.0), ({'Pasta'}, 'Butter', 1.0), ({'Butter'}, 'Pasta', 1.0), ({'Cheese'}, 'Beef', 1.0), ({'Beef'}, 'Cheese', 1.0), ({'Rice'}, 'Chicken', 1.0), ({'Chicken'}, 'Rice', 1.0), ({'Milk', 'Eggs'}, 'Bread', 1.0), ({'Bread', 'Eggs'}, 'Milk', 1.0), ({'Cereal', 'Milk'}, 'Bread', 1.0), ({'Cereal', 'Bread'}, 'Milk', 1.0), ({'Cheese', 'Eggs'}, 'Beef', 1.0), ({'Beef', 'Eggs'}, 'Cheese', 1.0), ({'Beef', 'Cheese'}, 'Eggs', 1.0)]
# Apriori Time: 0.0095 seconds
# Frequent Itemsets (Apriori):
#     support               itemsets
# 0       0.4                 (Milk)
# 1       0.4                (Bread)
# 2       0.4                 (Eggs)
# 3       0.2               (Butter)
# 4       0.2               (Cheese)
# 5       0.2               (Cereal)
# 6       0.2              (Chicken)
# 7       0.2                 (Beef)
# 8       0.2                (Pasta)
# 9       0.2                 (Rice)
# 10      0.4          (Bread, Milk)
# 11      0.2           (Milk, Eggs)
# 12      0.2         (Cereal, Milk)
# 13      0.2          (Bread, Eggs)
# 14      0.2        (Cereal, Bread)
# 15      0.2         (Cheese, Eggs)
# 16      0.2           (Beef, Eggs)
# 17      0.2        (Butter, Pasta)
# 18      0.2         (Beef, Cheese)
# 19      0.2        (Chicken, Rice)
# 20      0.2    (Bread, Milk, Eggs)
# 21      0.2  (Bread, Cereal, Milk)
# 22      0.2   (Beef, Cheese, Eggs)
# Association Rules (Apriori):
#         antecedents     consequents  antecedent support  consequent support  \
# 0           (Bread)          (Milk)                 0.4                 0.4
# 1            (Milk)         (Bread)                 0.4                 0.4
# 2          (Cereal)          (Milk)                 0.2                 0.4
# 3          (Cereal)         (Bread)                 0.2                 0.4
# 4          (Cheese)          (Eggs)                 0.2                 0.4
# 5            (Beef)          (Eggs)                 0.2                 0.4
# 6          (Butter)         (Pasta)                 0.2                 0.2
# 7           (Pasta)        (Butter)                 0.2                 0.2
# 8            (Beef)        (Cheese)                 0.2                 0.2
# 9          (Cheese)          (Beef)                 0.2                 0.2
# 10        (Chicken)          (Rice)                 0.2                 0.2
# 11           (Rice)       (Chicken)                 0.2                 0.2
# 12    (Bread, Eggs)          (Milk)                 0.2                 0.4
# 13     (Milk, Eggs)         (Bread)                 0.2                 0.4
# 14  (Cereal, Bread)          (Milk)                 0.2                 0.4
# 15   (Cereal, Milk)         (Bread)                 0.2                 0.4
# 16         (Cereal)   (Milk, Bread)                 0.2                 0.4
# 17   (Beef, Cheese)          (Eggs)                 0.2                 0.4
# 18     (Beef, Eggs)        (Cheese)                 0.2                 0.2
# 19   (Cheese, Eggs)          (Beef)                 0.2                 0.2
# 20           (Beef)  (Cheese, Eggs)                 0.2                 0.2
# 21         (Cheese)    (Beef, Eggs)                 0.2                 0.2
#
#     support  confidence  lift  leverage  conviction  zhangs_metric
# 0       0.4         1.0   2.5      0.24         inf           1.00
# 1       0.4         1.0   2.5      0.24         inf           1.00
# 2       0.2         1.0   2.5      0.12         inf           0.75
# 3       0.2         1.0   2.5      0.12         inf           0.75
# 4       0.2         1.0   2.5      0.12         inf           0.75
# 5       0.2         1.0   2.5      0.12         inf           0.75
# 6       0.2         1.0   5.0      0.16         inf           1.00
# 7       0.2         1.0   5.0      0.16         inf           1.00
# 8       0.2         1.0   5.0      0.16         inf           1.00
# 9       0.2         1.0   5.0      0.16         inf           1.00
# 10      0.2         1.0   5.0      0.16         inf           1.00
# 11      0.2         1.0   5.0      0.16         inf           1.00
# 12      0.2         1.0   2.5      0.12         inf           0.75
# 13      0.2         1.0   2.5      0.12         inf           0.75
# 14      0.2         1.0   2.5      0.12         inf           0.75
# 15      0.2         1.0   2.5      0.12         inf           0.75
# 16      0.2         1.0   2.5      0.12         inf           0.75
# 17      0.2         1.0   2.5      0.12         inf           0.75
# 18      0.2         1.0   5.0      0.16         inf           1.00
# 19      0.2         1.0   5.0      0.16         inf           1.00
# 20      0.2         1.0   5.0      0.16         inf           1.00
# 21      0.2         1.0   5.0      0.16         inf           1.00
# FP-Growth Time: 0.0052 seconds
# Frequent Itemsets (FP-Growth):
#     support               itemsets
# 0       0.4                 (Eggs)
# 1       0.4                (Bread)
# 2       0.4                 (Milk)
# 3       0.2                 (Rice)
# 4       0.2              (Chicken)
# 5       0.2                (Pasta)
# 6       0.2               (Butter)
# 7       0.2                 (Beef)
# 8       0.2               (Cheese)
# 9       0.2               (Cereal)
# 10      0.2          (Bread, Eggs)
# 11      0.4          (Bread, Milk)
# 12      0.2           (Milk, Eggs)
# 13      0.2    (Bread, Milk, Eggs)
# 14      0.2        (Chicken, Rice)
# 15      0.2        (Butter, Pasta)
# 16      0.2           (Beef, Eggs)
# 17      0.2         (Beef, Cheese)
# 18      0.2         (Cheese, Eggs)
# 19      0.2   (Beef, Cheese, Eggs)
# 20      0.2         (Cereal, Milk)
# 21      0.2        (Cereal, Bread)
# 22      0.2  (Bread, Cereal, Milk)
# Association Rules (FP-Growth):
#         antecedents     consequents  antecedent support  consequent support  \
# 0           (Bread)          (Milk)                 0.4                 0.4
# 1            (Milk)         (Bread)                 0.4                 0.4
# 2     (Bread, Eggs)          (Milk)                 0.2                 0.4
# 3      (Milk, Eggs)         (Bread)                 0.2                 0.4
# 4         (Chicken)          (Rice)                 0.2                 0.2
# 5            (Rice)       (Chicken)                 0.2                 0.2
# 6          (Butter)         (Pasta)                 0.2                 0.2
# 7           (Pasta)        (Butter)                 0.2                 0.2
# 8            (Beef)          (Eggs)                 0.2                 0.4
# 9            (Beef)        (Cheese)                 0.2                 0.2
# 10         (Cheese)          (Beef)                 0.2                 0.2
# 11         (Cheese)          (Eggs)                 0.2                 0.4
# 12   (Beef, Cheese)          (Eggs)                 0.2                 0.4
# 13     (Beef, Eggs)        (Cheese)                 0.2                 0.2
# 14   (Cheese, Eggs)          (Beef)                 0.2                 0.2
# 15           (Beef)  (Cheese, Eggs)                 0.2                 0.2
# 16         (Cheese)    (Beef, Eggs)                 0.2                 0.2
# 17         (Cereal)          (Milk)                 0.2                 0.4
# 18         (Cereal)         (Bread)                 0.2                 0.4
# 19  (Cereal, Bread)          (Milk)                 0.2                 0.4
# 20   (Cereal, Milk)         (Bread)                 0.2                 0.4
# 21         (Cereal)   (Milk, Bread)                 0.2                 0.4
#
#     support  confidence  lift  leverage  conviction  zhangs_metric
# 0       0.4         1.0   2.5      0.24         inf           1.00
# 1       0.4         1.0   2.5      0.24         inf           1.00
# 2       0.2         1.0   2.5      0.12         inf           0.75
# 3       0.2         1.0   2.5      0.12         inf           0.75
# 4       0.2         1.0   5.0      0.16         inf           1.00
# 5       0.2         1.0   5.0      0.16         inf           1.00
# 6       0.2         1.0   5.0      0.16         inf           1.00
# 7       0.2         1.0   5.0      0.16         inf           1.00
# 8       0.2         1.0   2.5      0.12         inf           0.75
# 9       0.2         1.0   5.0      0.16         inf           1.00
# 10      0.2         1.0   5.0      0.16         inf           1.00
# 11      0.2         1.0   2.5      0.12         inf           0.75
# 12      0.2         1.0   2.5      0.12         inf           0.75
# 13      0.2         1.0   5.0      0.16         inf           1.00
# 14      0.2         1.0   5.0      0.16         inf           1.00
# 15      0.2         1.0   5.0      0.16         inf           1.00
# 16      0.2         1.0   5.0      0.16         inf           1.00
# 17      0.2         1.0   2.5      0.12         inf           0.75
# 18      0.2         1.0   2.5      0.12         inf           0.75
# 19      0.2         1.0   2.5      0.12         inf           0.75
# 20      0.2         1.0   2.5      0.12         inf           0.75
# 21      0.2         1.0   2.5      0.12         inf           0.75

# %%
# !pip install mlxtend
import pandas as pd
from itertools import combinations
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.frequent_patterns import fpgrowth
import time

# Define items for Nike, Amazon, and Walmart
nike_items = [
    "Running Shoes", "Soccer Shoes", "Socks", "Swimming Shirt", "Dry Fit V-Neck",
    "Rash Guard", "Sweatshirts", "Hoodies", "Tech Pants", "Modern Pants"
]

amazon_items = [
    "Laptop", "Headphones", "Mouse", "Keyboard", "Monitor",
    "Smartphone", "Tablet", "Charger", "USB Cable", "HDMI Cable"
]

walmart_items = [
    "Milk", "Bread", "Eggs", "Butter", "Cheese",
    "Cereal", "Chicken", "Beef", "Pasta", "Rice"
]

# Transactions for Nike, Amazon, and Walmart
transactions_db = {
    "Nike": [
        ["Running Shoes", "Socks", "Sweatshirts"], ["Soccer Shoes", "Socks"], ["Swimming Shirt", "Dry Fit V-Neck"],
        ["Rash Guard", "Hoodies", "Tech Pants"], ["Modern Pants", "Sweatshirts"]
    ],
    "Amazon": [
        ["Laptop", "Headphones", "Mouse"], ["Smartphone", "Charger"], ["Tablet", "Keyboard"],
        ["Monitor", "HDMI Cable", "USB Cable"], ["Laptop", "Charger", "USB Cable"]
    ],
    "Walmart": [
        ["Milk", "Bread", "Eggs"], ["Chicken", "Rice"], ["Pasta", "Butter"],
        ["Beef", "Cheese", "Eggs"], ["Milk", "Cereal", "Bread"]
    ]
}

# Prompt user for input
min_support = float(input("Enter minimum support (e.g., 0.2): "))
min_confidence = float(input("Enter minimum confidence (e.g., 0.7): "))

# Convert transactions to DataFrame with binary encoding for apriori and fp-growth
def encode_transactions(transactions, items):
    encoded_vals = []
    for transaction in transactions:
        encoded_transaction = {item: (item in transaction) for item in items}
        encoded_vals.append(encoded_transaction)
    return pd.DataFrame(encoded_vals)

# Brute Force Implementation
def brute_force(transactions, items, min_support):
    start_time = time.time()

    def calculate_support(itemset, transactions):
        count = 0
        for transaction in transactions:
            if itemset.issubset(transaction):
                count += 1
        return count / len(transactions)

    def find_frequent_itemsets(items, transactions, size, min_support):
        itemsets = [set(combo) for combo in combinations(items, size)]
        frequent_itemsets = []
        for itemset in itemsets:
            support = calculate_support(itemset, transactions)
            if support >= min_support:
                frequent_itemsets.append((itemset, support))
        return frequent_itemsets

    k = 1
    frequent_itemsets = []
    while True:
        current_frequent_itemsets = find_frequent_itemsets(items, transactions, k, min_support)
        if len(current_frequent_itemsets) == 0:
            break
        frequent_itemsets.extend(current_frequent_itemsets)
        k += 1

    # Generate association rules
    rules = []
    for itemset, support in frequent_itemsets:
        if len(itemset) > 1:
            for consequent in itemset:
                antecedent = itemset - {consequent}
                if len(antecedent) > 0:
                    confidence = calculate_support(itemset, transactions) / calculate_support(antecedent, transactions)
                    if confidence >= min_confidence:
                        rules.append((list(antecedent), list(consequent), confidence, support))

    brute_force_time = time.time() - start_time
    return frequent_itemsets, rules, brute_force_time

# Apriori Implementation
def apriori_algorithm(df, min_support, min_confidence):
    start_time = time.time()
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    rules['antecedents'] = rules['antecedents'].apply(lambda x: list(x))
    rules['consequents'] = rules['consequents'].apply(lambda x: list(x))
    apriori_time = time.time() - start_time
    return frequent_itemsets, rules, apriori_time

# FP-Growth Implementation
def fpgrowth_algorithm(df, min_support, min_confidence):
    start_time = time.time()
    frequent_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    rules['antecedents'] = rules['antecedents'].apply(lambda x: list(x))
    rules['consequents'] = rules['consequents'].apply(lambda x: list(x))
    fpgrowth_time = time.time() - start_time
    return frequent_itemsets, rules, fpgrowth_time

# Main comparison function
def compare_algorithms(transactions_db, items_db, min_support, min_confidence):
    for store, transactions in transactions_db.items():
        print(f"\n--- {store} ---")
        items = items_db[store]
        transactions = [set(t) for t in transactions]

        # Brute Force
        frequent_itemsets_bf, rules_bf, bf_time = brute_force(transactions, items, min_support)
        print(f"Brute Force Time: {bf_time:.4f} seconds")
        print(f"Frequent Itemsets (Brute Force): {frequent_itemsets_bf}")

        if rules_bf:
            print("\nFinal Association Rules (Brute Force):")
            for idx, (antecedent, consequent, confidence, support) in enumerate(rules_bf, start=1):
                print(f"Rule {idx}: {antecedent} -> {consequent}")
                print(f"Confidence: {confidence * 100:.2f}%")
                print(f"Support: {support * 100:.2f}%\n")

        # Apriori
        df_encoded = encode_transactions(transactions, items)
        frequent_itemsets_ap, rules_ap, ap_time = apriori_algorithm(df_encoded, min_support, min_confidence)
        print(f"Apriori Time: {ap_time:.4f} seconds")
        print(f"Frequent Itemsets (Apriori):\n{frequent_itemsets_ap}")

        if not rules_ap.empty:
            print("\nFinal Association Rules (Apriori):")
            for idx, row in rules_ap.iterrows():
                print(f"Rule {idx + 1}: {row['antecedents']} -> {row['consequents']}")
                print(f"Confidence: {row['confidence'] * 100:.2f}%")
                print(f"Support: {row['support'] * 100:.2f}%\n")

        # FP-Growth
        frequent_itemsets_fp, rules_fp, fp_time = fpgrowth_algorithm(df_encoded, min_support, min_confidence)
        print(f"FP-Growth Time: {fp_time:.4f} seconds")
        print(f"Frequent Itemsets (FP-Growth):\n{frequent_itemsets_fp}")

        if not rules_fp.empty:
            print("\nFinal Association Rules (FP-Growth):")
            for idx, row in rules_fp.iterrows():
                print(f"Rule {idx + 1}: {row['antecedents']} -> {row['consequents']}")
                print(f"Confidence: {row['confidence'] * 100:.2f}%")
                print(f"Support: {row['support'] * 100:.2f}%\n")

# Dictionary of item sets for each store
items_db = {
    "Nike": nike_items,
    "Amazon": amazon_items,
    "Walmart": walmart_items
}

# Run the comparison for Nike, Amazon, and Walmart
compare_algorithms(transactions_db, items_db, min_support, min_confidence)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.10/dist-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Enter minimum support (e.g., 0.2): 0.2
# Enter minimum confidence (e.g., 0.7): 0.8
#
# --- Nike ---
# Brute Force Time: 0.0009 seconds
# Frequent Itemsets (Brute Force): [({'Running Shoes'}, 0.2), ({'Soccer Shoes'}, 0.2), ({'Socks'}, 0.4), ({'Swimming Shirt'}, 0.2), ({'Dry Fit V-Neck'}, 0.2), ({'Rash Guard'}, 0.2), ({'Sweatshirts'}, 0.4), ({'Hoodies'}, 0.2), ({'Tech Pants'}, 0.2), ({'Modern Pants'}, 0.2), ({'Running Shoes', 'Socks'}, 0.2), ({'Running Shoes', 'Sweatshirts'}, 0.2), ({'Socks', 'Soccer Shoes'}, 0.2), ({'Socks', 'Sweatshirts'}, 0.2), ({'Swimming Shirt', 'Dry Fit V-Neck'}, 0.2), ({'Hoodies', 'Rash Guard'}, 0.2), ({'Tech Pants', 'Rash Guard'}, 0.2), ({'Modern Pants', 'Sweatshirts'}, 0.2), ({'Hoodies', 'Tech Pants'}, 0.2), ({'Running Shoes', 'Socks', 'Sweatshirts'}, 0.2), ({'Hoodies', 'Tech Pants', 'Rash Guard'}, 0.2)]
#
# Final Association Rules (Brute Force):
# Rule 1: ['Running Shoes'] -> ['S', 'o', 'c', 'k', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 2: ['Running Shoes'] -> ['S', 'w', 'e', 'a', 't', 's', 'h', 'i', 'r', 't', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 3: ['Soccer Shoes'] -> ['S', 'o', 'c', 'k', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 4: ['Dry Fit V-Neck'] -> ['S', 'w', 'i', 'm', 'm', 'i', 'n', 'g', ' ', 'S', 'h', 'i', 'r', 't']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 5: ['Swimming Shirt'] -> ['D', 'r', 'y', ' ', 'F', 'i', 't', ' ', 'V', '-', 'N', 'e', 'c', 'k']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 6: ['Rash Guard'] -> ['H', 'o', 'o', 'd', 'i', 'e', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 7: ['Hoodies'] -> ['R', 'a', 's', 'h', ' ', 'G', 'u', 'a', 'r', 'd']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 8: ['Rash Guard'] -> ['T', 'e', 'c', 'h', ' ', 'P', 'a', 'n', 't', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 9: ['Tech Pants'] -> ['R', 'a', 's', 'h', ' ', 'G', 'u', 'a', 'r', 'd']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 10: ['Modern Pants'] -> ['S', 'w', 'e', 'a', 't', 's', 'h', 'i', 'r', 't', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 11: ['Tech Pants'] -> ['H', 'o', 'o', 'd', 'i', 'e', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 12: ['Hoodies'] -> ['T', 'e', 'c', 'h', ' ', 'P', 'a', 'n', 't', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 13: ['Socks', 'Sweatshirts'] -> ['R', 'u', 'n', 'n', 'i', 'n', 'g', ' ', 'S', 'h', 'o', 'e', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 14: ['Running Shoes', 'Sweatshirts'] -> ['S', 'o', 'c', 'k', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 15: ['Running Shoes', 'Socks'] -> ['S', 'w', 'e', 'a', 't', 's', 'h', 'i', 'r', 't', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 16: ['Tech Pants', 'Rash Guard'] -> ['H', 'o', 'o', 'd', 'i', 'e', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 17: ['Hoodies', 'Rash Guard'] -> ['T', 'e', 'c', 'h', ' ', 'P', 'a', 'n', 't', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 18: ['Hoodies', 'Tech Pants'] -> ['R', 'a', 's', 'h', ' ', 'G', 'u', 'a', 'r', 'd']
# Confidence: 100.00%
# Support: 20.00%
#
# Apriori Time: 0.0217 seconds
# Frequent Itemsets (Apriori):
#     support                             itemsets
# 0       0.2                      (Running Shoes)
# 1       0.2                       (Soccer Shoes)
# 2       0.4                              (Socks)
# 3       0.2                     (Swimming Shirt)
# 4       0.2                     (Dry Fit V-Neck)
# 5       0.2                         (Rash Guard)
# 6       0.4                        (Sweatshirts)
# 7       0.2                            (Hoodies)
# 8       0.2                         (Tech Pants)
# 9       0.2                       (Modern Pants)
# 10      0.2               (Running Shoes, Socks)
# 11      0.2         (Running Shoes, Sweatshirts)
# 12      0.2                (Socks, Soccer Shoes)
# 13      0.2                 (Socks, Sweatshirts)
# 14      0.2     (Swimming Shirt, Dry Fit V-Neck)
# 15      0.2                (Hoodies, Rash Guard)
# 16      0.2             (Tech Pants, Rash Guard)
# 17      0.2          (Modern Pants, Sweatshirts)
# 18      0.2                (Hoodies, Tech Pants)
# 19      0.2  (Running Shoes, Socks, Sweatshirts)
# 20      0.2    (Hoodies, Tech Pants, Rash Guard)
#
# Final Association Rules (Apriori):
# Rule 1: ['Running Shoes'] -> ['Socks']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 2: ['Running Shoes'] -> ['Sweatshirts']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 3: ['Soccer Shoes'] -> ['Socks']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 4: ['Swimming Shirt'] -> ['Dry Fit V-Neck']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 5: ['Dry Fit V-Neck'] -> ['Swimming Shirt']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 6: ['Hoodies'] -> ['Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 7: ['Rash Guard'] -> ['Hoodies']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 8: ['Tech Pants'] -> ['Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 9: ['Rash Guard'] -> ['Tech Pants']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 10: ['Modern Pants'] -> ['Sweatshirts']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 11: ['Hoodies'] -> ['Tech Pants']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 12: ['Tech Pants'] -> ['Hoodies']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 13: ['Running Shoes', 'Socks'] -> ['Sweatshirts']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 14: ['Running Shoes', 'Sweatshirts'] -> ['Socks']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 15: ['Socks', 'Sweatshirts'] -> ['Running Shoes']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 16: ['Running Shoes'] -> ['Socks', 'Sweatshirts']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 17: ['Hoodies', 'Tech Pants'] -> ['Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 18: ['Hoodies', 'Rash Guard'] -> ['Tech Pants']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 19: ['Tech Pants', 'Rash Guard'] -> ['Hoodies']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 20: ['Hoodies'] -> ['Tech Pants', 'Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 21: ['Tech Pants'] -> ['Hoodies', 'Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 22: ['Rash Guard'] -> ['Hoodies', 'Tech Pants']
# Confidence: 100.00%
# Support: 20.00%
#
# FP-Growth Time: 0.0179 seconds
# Frequent Itemsets (FP-Growth):
#     support                             itemsets
# 0       0.4                        (Sweatshirts)
# 1       0.4                              (Socks)
# 2       0.2                      (Running Shoes)
# 3       0.2                       (Soccer Shoes)
# 4       0.2                     (Dry Fit V-Neck)
# 5       0.2                     (Swimming Shirt)
# 6       0.2                         (Tech Pants)
# 7       0.2                            (Hoodies)
# 8       0.2                         (Rash Guard)
# 9       0.2                       (Modern Pants)
# 10      0.2                 (Socks, Sweatshirts)
# 11      0.2               (Running Shoes, Socks)
# 12      0.2         (Running Shoes, Sweatshirts)
# 13      0.2  (Running Shoes, Socks, Sweatshirts)
# 14      0.2                (Socks, Soccer Shoes)
# 15      0.2     (Swimming Shirt, Dry Fit V-Neck)
# 16      0.2                (Hoodies, Tech Pants)
# 17      0.2                (Hoodies, Rash Guard)
# 18      0.2             (Tech Pants, Rash Guard)
# 19      0.2    (Hoodies, Tech Pants, Rash Guard)
# 20      0.2          (Modern Pants, Sweatshirts)
#
# Final Association Rules (FP-Growth):
# Rule 1: ['Running Shoes'] -> ['Socks']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 2: ['Running Shoes'] -> ['Sweatshirts']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 3: ['Running Shoes', 'Socks'] -> ['Sweatshirts']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 4: ['Running Shoes', 'Sweatshirts'] -> ['Socks']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 5: ['Socks', 'Sweatshirts'] -> ['Running Shoes']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 6: ['Running Shoes'] -> ['Socks', 'Sweatshirts']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 7: ['Soccer Shoes'] -> ['Socks']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 8: ['Swimming Shirt'] -> ['Dry Fit V-Neck']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 9: ['Dry Fit V-Neck'] -> ['Swimming Shirt']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 10: ['Hoodies'] -> ['Tech Pants']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 11: ['Tech Pants'] -> ['Hoodies']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 12: ['Hoodies'] -> ['Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 13: ['Rash Guard'] -> ['Hoodies']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 14: ['Tech Pants'] -> ['Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 15: ['Rash Guard'] -> ['Tech Pants']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 16: ['Hoodies', 'Tech Pants'] -> ['Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 17: ['Hoodies', 'Rash Guard'] -> ['Tech Pants']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 18: ['Tech Pants', 'Rash Guard'] -> ['Hoodies']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 19: ['Hoodies'] -> ['Tech Pants', 'Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 20: ['Tech Pants'] -> ['Hoodies', 'Rash Guard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 21: ['Rash Guard'] -> ['Hoodies', 'Tech Pants']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 22: ['Modern Pants'] -> ['Sweatshirts']
# Confidence: 100.00%
# Support: 20.00%
#
#
# --- Amazon ---
# Brute Force Time: 0.0020 seconds
# Frequent Itemsets (Brute Force): [({'Laptop'}, 0.4), ({'Headphones'}, 0.2), ({'Mouse'}, 0.2), ({'Keyboard'}, 0.2), ({'Monitor'}, 0.2), ({'Smartphone'}, 0.2), ({'Tablet'}, 0.2), ({'Charger'}, 0.4), ({'USB Cable'}, 0.4), ({'HDMI Cable'}, 0.2), ({'Headphones', 'Laptop'}, 0.2), ({'Mouse', 'Laptop'}, 0.2), ({'Laptop', 'Charger'}, 0.2), ({'USB Cable', 'Laptop'}, 0.2), ({'Headphones', 'Mouse'}, 0.2), ({'Keyboard', 'Tablet'}, 0.2), ({'USB Cable', 'Monitor'}, 0.2), ({'HDMI Cable', 'Monitor'}, 0.2), ({'Charger', 'Smartphone'}, 0.2), ({'USB Cable', 'Charger'}, 0.2), ({'HDMI Cable', 'USB Cable'}, 0.2), ({'Headphones', 'Laptop', 'Mouse'}, 0.2), ({'USB Cable', 'Laptop', 'Charger'}, 0.2), ({'HDMI Cable', 'USB Cable', 'Monitor'}, 0.2)]
#
# Final Association Rules (Brute Force):
# Rule 1: ['Headphones'] -> ['L', 'a', 'p', 't', 'o', 'p']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 2: ['Mouse'] -> ['L', 'a', 'p', 't', 'o', 'p']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 3: ['Mouse'] -> ['H', 'e', 'a', 'd', 'p', 'h', 'o', 'n', 'e', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 4: ['Headphones'] -> ['M', 'o', 'u', 's', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 5: ['Tablet'] -> ['K', 'e', 'y', 'b', 'o', 'a', 'r', 'd']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 6: ['Keyboard'] -> ['T', 'a', 'b', 'l', 'e', 't']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 7: ['Monitor'] -> ['U', 'S', 'B', ' ', 'C', 'a', 'b', 'l', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 8: ['Monitor'] -> ['H', 'D', 'M', 'I', ' ', 'C', 'a', 'b', 'l', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 9: ['HDMI Cable'] -> ['M', 'o', 'n', 'i', 't', 'o', 'r']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 10: ['Smartphone'] -> ['C', 'h', 'a', 'r', 'g', 'e', 'r']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 11: ['HDMI Cable'] -> ['U', 'S', 'B', ' ', 'C', 'a', 'b', 'l', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 12: ['Mouse', 'Laptop'] -> ['H', 'e', 'a', 'd', 'p', 'h', 'o', 'n', 'e', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 13: ['Headphones', 'Mouse'] -> ['L', 'a', 'p', 't', 'o', 'p']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 14: ['Headphones', 'Laptop'] -> ['M', 'o', 'u', 's', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 15: ['Laptop', 'Charger'] -> ['U', 'S', 'B', ' ', 'C', 'a', 'b', 'l', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 16: ['USB Cable', 'Charger'] -> ['L', 'a', 'p', 't', 'o', 'p']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 17: ['USB Cable', 'Laptop'] -> ['C', 'h', 'a', 'r', 'g', 'e', 'r']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 18: ['USB Cable', 'Monitor'] -> ['H', 'D', 'M', 'I', ' ', 'C', 'a', 'b', 'l', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 19: ['HDMI Cable', 'Monitor'] -> ['U', 'S', 'B', ' ', 'C', 'a', 'b', 'l', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 20: ['USB Cable', 'HDMI Cable'] -> ['M', 'o', 'n', 'i', 't', 'o', 'r']
# Confidence: 100.00%
# Support: 20.00%
#
# Apriori Time: 0.0216 seconds
# Frequent Itemsets (Apriori):
#     support                          itemsets
# 0       0.4                          (Laptop)
# 1       0.2                      (Headphones)
# 2       0.2                           (Mouse)
# 3       0.2                        (Keyboard)
# 4       0.2                         (Monitor)
# 5       0.2                      (Smartphone)
# 6       0.2                          (Tablet)
# 7       0.4                         (Charger)
# 8       0.4                       (USB Cable)
# 9       0.2                      (HDMI Cable)
# 10      0.2              (Headphones, Laptop)
# 11      0.2                   (Mouse, Laptop)
# 12      0.2                 (Laptop, Charger)
# 13      0.2               (USB Cable, Laptop)
# 14      0.2               (Headphones, Mouse)
# 15      0.2                (Keyboard, Tablet)
# 16      0.2              (USB Cable, Monitor)
# 17      0.2             (HDMI Cable, Monitor)
# 18      0.2             (Charger, Smartphone)
# 19      0.2              (USB Cable, Charger)
# 20      0.2           (HDMI Cable, USB Cable)
# 21      0.2       (Headphones, Laptop, Mouse)
# 22      0.2      (USB Cable, Laptop, Charger)
# 23      0.2  (HDMI Cable, USB Cable, Monitor)
#
# Final Association Rules (Apriori):
# Rule 1: ['Headphones'] -> ['Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 2: ['Mouse'] -> ['Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 3: ['Headphones'] -> ['Mouse']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 4: ['Mouse'] -> ['Headphones']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 5: ['Keyboard'] -> ['Tablet']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 6: ['Tablet'] -> ['Keyboard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 7: ['Monitor'] -> ['USB Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 8: ['HDMI Cable'] -> ['Monitor']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 9: ['Monitor'] -> ['HDMI Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 10: ['Smartphone'] -> ['Charger']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 11: ['HDMI Cable'] -> ['USB Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 12: ['Headphones', 'Laptop'] -> ['Mouse']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 13: ['Headphones', 'Mouse'] -> ['Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 14: ['Mouse', 'Laptop'] -> ['Headphones']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 15: ['Headphones'] -> ['Mouse', 'Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 16: ['Mouse'] -> ['Headphones', 'Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 17: ['USB Cable', 'Laptop'] -> ['Charger']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 18: ['USB Cable', 'Charger'] -> ['Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 19: ['Laptop', 'Charger'] -> ['USB Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 20: ['USB Cable', 'HDMI Cable'] -> ['Monitor']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 21: ['HDMI Cable', 'Monitor'] -> ['USB Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 22: ['USB Cable', 'Monitor'] -> ['HDMI Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 23: ['HDMI Cable'] -> ['USB Cable', 'Monitor']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 24: ['Monitor'] -> ['USB Cable', 'HDMI Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# FP-Growth Time: 0.0095 seconds
# Frequent Itemsets (FP-Growth):
#     support                          itemsets
# 0       0.4                          (Laptop)
# 1       0.2                           (Mouse)
# 2       0.2                      (Headphones)
# 3       0.4                         (Charger)
# 4       0.2                      (Smartphone)
# 5       0.2                          (Tablet)
# 6       0.2                        (Keyboard)
# 7       0.4                       (USB Cable)
# 8       0.2                      (HDMI Cable)
# 9       0.2                         (Monitor)
# 10      0.2                 (Laptop, Charger)
# 11      0.2               (USB Cable, Laptop)
# 12      0.2      (USB Cable, Laptop, Charger)
# 13      0.2                   (Mouse, Laptop)
# 14      0.2               (Headphones, Mouse)
# 15      0.2              (Headphones, Laptop)
# 16      0.2       (Headphones, Laptop, Mouse)
# 17      0.2              (USB Cable, Charger)
# 18      0.2             (Charger, Smartphone)
# 19      0.2                (Keyboard, Tablet)
# 20      0.2           (HDMI Cable, USB Cable)
# 21      0.2             (HDMI Cable, Monitor)
# 22      0.2              (USB Cable, Monitor)
# 23      0.2  (HDMI Cable, USB Cable, Monitor)
#
# Final Association Rules (FP-Growth):
# Rule 1: ['USB Cable', 'Laptop'] -> ['Charger']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 2: ['USB Cable', 'Charger'] -> ['Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 3: ['Laptop', 'Charger'] -> ['USB Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 4: ['Mouse'] -> ['Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 5: ['Headphones'] -> ['Mouse']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 6: ['Mouse'] -> ['Headphones']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 7: ['Headphones'] -> ['Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 8: ['Headphones', 'Laptop'] -> ['Mouse']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 9: ['Headphones', 'Mouse'] -> ['Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 10: ['Mouse', 'Laptop'] -> ['Headphones']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 11: ['Headphones'] -> ['Mouse', 'Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 12: ['Mouse'] -> ['Headphones', 'Laptop']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 13: ['Smartphone'] -> ['Charger']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 14: ['Keyboard'] -> ['Tablet']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 15: ['Tablet'] -> ['Keyboard']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 16: ['HDMI Cable'] -> ['USB Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 17: ['HDMI Cable'] -> ['Monitor']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 18: ['Monitor'] -> ['HDMI Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 19: ['Monitor'] -> ['USB Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 20: ['USB Cable', 'HDMI Cable'] -> ['Monitor']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 21: ['HDMI Cable', 'Monitor'] -> ['USB Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 22: ['USB Cable', 'Monitor'] -> ['HDMI Cable']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 23: ['HDMI Cable'] -> ['USB Cable', 'Monitor']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 24: ['Monitor'] -> ['USB Cable', 'HDMI Cable']
# Confidence: 100.00%
# Support: 20.00%
#
#
# --- Walmart ---
# Brute Force Time: 0.0007 seconds
# Frequent Itemsets (Brute Force): [({'Milk'}, 0.4), ({'Bread'}, 0.4), ({'Eggs'}, 0.4), ({'Butter'}, 0.2), ({'Cheese'}, 0.2), ({'Cereal'}, 0.2), ({'Chicken'}, 0.2), ({'Beef'}, 0.2), ({'Pasta'}, 0.2), ({'Rice'}, 0.2), ({'Bread', 'Milk'}, 0.4), ({'Milk', 'Eggs'}, 0.2), ({'Cereal', 'Milk'}, 0.2), ({'Bread', 'Eggs'}, 0.2), ({'Cereal', 'Bread'}, 0.2), ({'Cheese', 'Eggs'}, 0.2), ({'Beef', 'Eggs'}, 0.2), ({'Butter', 'Pasta'}, 0.2), ({'Beef', 'Cheese'}, 0.2), ({'Chicken', 'Rice'}, 0.2), ({'Bread', 'Milk', 'Eggs'}, 0.2), ({'Bread', 'Cereal', 'Milk'}, 0.2), ({'Beef', 'Cheese', 'Eggs'}, 0.2)]
#
# Final Association Rules (Brute Force):
# Rule 1: ['Milk'] -> ['B', 'r', 'e', 'a', 'd']
# Confidence: 100.00%
# Support: 40.00%
#
# Rule 2: ['Bread'] -> ['M', 'i', 'l', 'k']
# Confidence: 100.00%
# Support: 40.00%
#
# Rule 3: ['Cereal'] -> ['M', 'i', 'l', 'k']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 4: ['Cereal'] -> ['B', 'r', 'e', 'a', 'd']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 5: ['Cheese'] -> ['E', 'g', 'g', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 6: ['Beef'] -> ['E', 'g', 'g', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 7: ['Pasta'] -> ['B', 'u', 't', 't', 'e', 'r']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 8: ['Butter'] -> ['P', 'a', 's', 't', 'a']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 9: ['Cheese'] -> ['B', 'e', 'e', 'f']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 10: ['Beef'] -> ['C', 'h', 'e', 'e', 's', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 11: ['Rice'] -> ['C', 'h', 'i', 'c', 'k', 'e', 'n']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 12: ['Chicken'] -> ['R', 'i', 'c', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 13: ['Milk', 'Eggs'] -> ['B', 'r', 'e', 'a', 'd']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 14: ['Bread', 'Eggs'] -> ['M', 'i', 'l', 'k']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 15: ['Cereal', 'Milk'] -> ['B', 'r', 'e', 'a', 'd']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 16: ['Cereal', 'Bread'] -> ['M', 'i', 'l', 'k']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 17: ['Cheese', 'Eggs'] -> ['B', 'e', 'e', 'f']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 18: ['Beef', 'Eggs'] -> ['C', 'h', 'e', 'e', 's', 'e']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 19: ['Beef', 'Cheese'] -> ['E', 'g', 'g', 's']
# Confidence: 100.00%
# Support: 20.00%
#
# Apriori Time: 0.0368 seconds
# Frequent Itemsets (Apriori):
#     support               itemsets
# 0       0.4                 (Milk)
# 1       0.4                (Bread)
# 2       0.4                 (Eggs)
# 3       0.2               (Butter)
# 4       0.2               (Cheese)
# 5       0.2               (Cereal)
# 6       0.2              (Chicken)
# 7       0.2                 (Beef)
# 8       0.2                (Pasta)
# 9       0.2                 (Rice)
# 10      0.4          (Bread, Milk)
# 11      0.2           (Milk, Eggs)
# 12      0.2         (Cereal, Milk)
# 13      0.2          (Bread, Eggs)
# 14      0.2        (Cereal, Bread)
# 15      0.2         (Cheese, Eggs)
# 16      0.2           (Beef, Eggs)
# 17      0.2        (Butter, Pasta)
# 18      0.2         (Beef, Cheese)
# 19      0.2        (Chicken, Rice)
# 20      0.2    (Bread, Milk, Eggs)
# 21      0.2  (Bread, Cereal, Milk)
# 22      0.2   (Beef, Cheese, Eggs)
#
# Final Association Rules (Apriori):
# Rule 1: ['Bread'] -> ['Milk']
# Confidence: 100.00%
# Support: 40.00%
#
# Rule 2: ['Milk'] -> ['Bread']
# Confidence: 100.00%
# Support: 40.00%
#
# Rule 3: ['Cereal'] -> ['Milk']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 4: ['Cereal'] -> ['Bread']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 5: ['Cheese'] -> ['Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 6: ['Beef'] -> ['Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 7: ['Butter'] -> ['Pasta']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 8: ['Pasta'] -> ['Butter']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 9: ['Beef'] -> ['Cheese']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 10: ['Cheese'] -> ['Beef']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 11: ['Chicken'] -> ['Rice']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 12: ['Rice'] -> ['Chicken']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 13: ['Bread', 'Eggs'] -> ['Milk']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 14: ['Milk', 'Eggs'] -> ['Bread']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 15: ['Cereal', 'Bread'] -> ['Milk']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 16: ['Cereal', 'Milk'] -> ['Bread']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 17: ['Cereal'] -> ['Milk', 'Bread']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 18: ['Beef', 'Cheese'] -> ['Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 19: ['Beef', 'Eggs'] -> ['Cheese']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 20: ['Cheese', 'Eggs'] -> ['Beef']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 21: ['Beef'] -> ['Cheese', 'Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 22: ['Cheese'] -> ['Beef', 'Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# FP-Growth Time: 0.0213 seconds
# Frequent Itemsets (FP-Growth):
#     support               itemsets
# 0       0.4                 (Eggs)
# 1       0.4                (Bread)
# 2       0.4                 (Milk)
# 3       0.2                 (Rice)
# 4       0.2              (Chicken)
# 5       0.2                (Pasta)
# 6       0.2               (Butter)
# 7       0.2                 (Beef)
# 8       0.2               (Cheese)
# 9       0.2               (Cereal)
# 10      0.2          (Bread, Eggs)
# 11      0.4          (Bread, Milk)
# 12      0.2           (Milk, Eggs)
# 13      0.2    (Bread, Milk, Eggs)
# 14      0.2        (Chicken, Rice)
# 15      0.2        (Butter, Pasta)
# 16      0.2           (Beef, Eggs)
# 17      0.2         (Beef, Cheese)
# 18      0.2         (Cheese, Eggs)
# 19      0.2   (Beef, Cheese, Eggs)
# 20      0.2         (Cereal, Milk)
# 21      0.2        (Cereal, Bread)
# 22      0.2  (Bread, Cereal, Milk)
#
# Final Association Rules (FP-Growth):
# Rule 1: ['Bread'] -> ['Milk']
# Confidence: 100.00%
# Support: 40.00%
#
# Rule 2: ['Milk'] -> ['Bread']
# Confidence: 100.00%
# Support: 40.00%
#
# Rule 3: ['Bread', 'Eggs'] -> ['Milk']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 4: ['Milk', 'Eggs'] -> ['Bread']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 5: ['Chicken'] -> ['Rice']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 6: ['Rice'] -> ['Chicken']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 7: ['Butter'] -> ['Pasta']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 8: ['Pasta'] -> ['Butter']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 9: ['Beef'] -> ['Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 10: ['Beef'] -> ['Cheese']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 11: ['Cheese'] -> ['Beef']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 12: ['Cheese'] -> ['Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 13: ['Beef', 'Cheese'] -> ['Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 14: ['Beef', 'Eggs'] -> ['Cheese']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 15: ['Cheese', 'Eggs'] -> ['Beef']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 16: ['Beef'] -> ['Cheese', 'Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 17: ['Cheese'] -> ['Beef', 'Eggs']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 18: ['Cereal'] -> ['Milk']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 19: ['Cereal'] -> ['Bread']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 20: ['Cereal', 'Bread'] -> ['Milk']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 21: ['Cereal', 'Milk'] -> ['Bread']
# Confidence: 100.00%
# Support: 20.00%
#
# Rule 22: ['Cereal'] -> ['Milk', 'Bread']
# Confidence: 100.00%
# Support: 20.00%

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
